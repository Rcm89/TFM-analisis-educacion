# %%
# Para trabajar con regex
# -----------------------------------------------------------------------
import re

# Para trabajar con ficheros
# -----------------------------------------------------------------------
import os


# Para trabajar con los DataFrames
# -----------------------------------------------------------------------
import pandas as pd

# Para poner barras progreso
# -----------------------------------------------------------------------
from tqdm import tqdm



# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Ignorar warings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# Librerias para generar gráficas
# ----------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Cargamos los archivos del INE

# %%
df_censo_2022 = pd.read_csv("datos/ine/censo_2022.csv", encoding= 'latin-1', sep=';')

# %%
df_censo_2022.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias Nacionalidad  \
# 0  Total Nacional                              NaN         NaN        Total
# 1  Total Nacional                     01 Andalucía         NaN        Total
# 2  Total Nacional                     01 Andalucía   29 Málaga        Total
# 3  Total Nacional                     01 Andalucía     23 Jaén        Total
# 4  Total Nacional                     01 Andalucía  04 Almería        Total
#
#     Sexo              Edad  Periodo       Total
# 0  Total  Todas las edades     2022  47.486.727
# 1  Total  Todas las edades     2022   8.511.167
# 2  Total  Todas las edades     2022   1.715.109
# 3  Total  Todas las edades     2022     624.191
# 4  Total  Todas las edades     2022     739.541

# %%
df_censo_2022.sample(35)
# Out:
#     Total Nacional Comunidades y Ciudades Autónomas           Provincias  \
# 41  Total Nacional                      09 Cataluña            17 Girona
# 43  Total Nacional                      09 Cataluña         43 Tarragona
# 69  Total Nacional                         18 Ceuta             51 Ceuta
# 5   Total Nacional                     01 Andalucía            21 Huelva
# 60  Total Nacional   15 Navarra, Comunidad Foral de                  NaN
# 34  Total Nacional               07 Castilla y León             05 Ávila
# 22  Total Nacional                     06 Cantabria         39 Cantabria
# 37  Total Nacional               07 Castilla y León         37 Salamanca
# 50  Total Nacional                   11 Extremadura           06 Badajoz
# 58  Total Nacional             14 Murcia, Región de                  NaN
# 26  Total Nacional          08 Castilla - La Mancha          02 Albacete
# 59  Total Nacional             14 Murcia, Región de            30 Murcia
# 1   Total Nacional                     01 Andalucía                  NaN
# 61  Total Nacional   15 Navarra, Comunidad Foral de           31 Navarra
# 49  Total Nacional                   11 Extremadura           10 Cáceres
# 48  Total Nacional                   11 Extremadura                  NaN
# 15  Total Nacional       03 Asturias, Principado de          33 Asturias
# 62  Total Nacional                    16 País Vasco                  NaN
# 27  Total Nacional          08 Castilla - La Mancha            45 Toledo
# 66  Total Nacional                     17 Rioja, La                  NaN
# 46  Total Nacional          10 Comunitat Valenciana  03 Alicante/Alacant
# 35  Total Nacional               07 Castilla y León            49 Zamora
# 6   Total Nacional                     01 Andalucía             11 Cádiz
# 2   Total Nacional                     01 Andalucía            29 Málaga
# 30  Total Nacional               07 Castilla y León            09 Burgos
# 57  Total Nacional          13 Madrid, Comunidad de            28 Madrid
# 29  Total Nacional               07 Castilla y León                  NaN
# 18  Total Nacional                      05 Canarias                  NaN
# 24  Total Nacional          08 Castilla - La Mancha       19 Guadalajara
# 21  Total Nacional                     06 Cantabria                  NaN
# 71  Total Nacional                       19 Melilla           52 Melilla
# 32  Total Nacional               07 Castilla y León           40 Segovia
# 4   Total Nacional                     01 Andalucía           04 Almería
# 63  Total Nacional                    16 País Vasco           48 Bizkaia
# 9   Total Nacional                     01 Andalucía           14 Córdoba
#
#    Nacionalidad   Sexo              Edad  Periodo      Total
# 41        Total  Total  Todas las edades     2022    790.432
# 43        Total  Total  Todas las edades     2022    830.906
# 69        Total  Total  Todas las edades     2022     83.051
# 5         Total  Total  Todas las edades     2022    531.094
# 60        Total  Total  Todas las edades     2022    664.514
# 34        Total  Total  Todas las edades     2022    159.102
# 22        Total  Total  Todas las edades     2022    585.450
# 37        Total  Total  Todas las edades     2022    326.285
# 50        Total  Total  Todas las edades     2022    667.851
# 58        Total  Total  Todas las edades     2022  1.529.658
# 26        Total  Total  Todas las edades     2022    385.967
# 59        Total  Total  Todas las edades     2022  1.529.658
# 1         Total  Total  Todas las edades     2022  8.511.167
# 61        Total  Total  Todas las edades     2022    664.514
# 49        Total  Total  Todas las edades     2022    388.957
# 48        Total  Total  Todas las edades     2022  1.056.808
# 15        Total  Total  Todas las edades     2022  1.004.960
# 62        Total  Total  Todas las edades     2022  2.205.826
# 27        Total  Total  Todas las edades     2022    716.309
# 66        Total  Total  Todas las edades     2022    319.617
# 46        Total  Total  Todas las edades     2022  1.907.494
# 35        Total  Total  Todas las edades     2022    167.868
# 6         Total  Total  Todas las edades     2022  1.250.545
# 2         Total  Total  Todas las edades     2022  1.715.109
# 30        Total  Total  Todas las edades     2022    354.846
# 57        Total  Total  Todas las edades     2022  6.743.254
# 29        Total  Total  Todas las edades     2022  2.375.583
# 18        Total  Total  Todas las edades     2022  2.185.607
# 24        Total  Total  Todas las edades     2022    268.412
# 21        Total  Total  Todas las edades     2022    585.450
# 71        Total  Total  Todas las edades     2022     84.932
# 32        Total  Total  Todas las edades     2022    153.731
# 4         Total  Total  Todas las edades     2022    739.541
# 63        Total  Total  Todas las edades     2022  1.148.677
# 9         Total  Total  Todas las edades     2022    775.110

# %% [markdown]
# Eliminamos las columnas de Edad, Nacionalidad y Sexo pues no interesan para el analisis. Los datos relevantes de estas categorías los obtenemos asociados a nivel educativo en otro archivo del INE.

# %%
# Eliminar la columna 'Edad'
df_censo_2022.drop(columns=['Edad','Nacionalidad','Sexo'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_censo_2022.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  Periodo  \
# 0  Total Nacional                              NaN         NaN     2022
# 1  Total Nacional                     01 Andalucía         NaN     2022
# 2  Total Nacional                     01 Andalucía   29 Málaga     2022
# 3  Total Nacional                     01 Andalucía     23 Jaén     2022
# 4  Total Nacional                     01 Andalucía  04 Almería     2022
#
#         Total
# 0  47.486.727
# 1   8.511.167
# 2   1.715.109
# 3     624.191
# 4     739.541

# %% [markdown]
# Formatemaos la columna "Total"

# %%
# Convertimos la columna "Total" a int64
df_censo_2022['Total'] = df_censo_2022['Total'].str.replace('.', '').astype('int64')
df_censo_2022.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  Periodo  \
# 0  Total Nacional                              NaN         NaN     2022
# 1  Total Nacional                     01 Andalucía         NaN     2022
# 2  Total Nacional                     01 Andalucía   29 Málaga     2022
# 3  Total Nacional                     01 Andalucía     23 Jaén     2022
# 4  Total Nacional                     01 Andalucía  04 Almería     2022
#
#       Total
# 0  47486727
# 1   8511167
# 2   1715109
# 3    624191
# 4    739541

# %% [markdown]
# A partir del DataFrame df_censo_2022 vamos a crear tres dataframes con la información a nivel nacional, autonómico y provincial respectivamente

# %%
# Filtrar el DataFrame para obtener los tres niveles de información

# Nivel nacional: Filtramos donde "Comunidades y Ciudades Autónomas" sea NaN
df_censo_2022_nacional = df_censo_2022[df_censo_2022['Comunidades y Ciudades Autónomas'].isna()].copy().reset_index(drop=True)

# Nivel autonómico: Filtramos donde "Comunidades y Ciudades Autónomas" no sea NaN y "Provincias" sea NaN
df_censo_2022_autonomico = df_censo_2022[df_censo_2022['Comunidades y Ciudades Autónomas'].notna() & df_censo_2022['Provincias'].isna()].copy().reset_index(drop=True)

# Nivel provincial: Filtramos donde "Provincias" no sea NaN
df_censo_2022_provincial = df_censo_2022[df_censo_2022['Provincias'].notna()].copy().reset_index(drop=True)

# %% [markdown]
# Verificamos que los dataframes filtrados se han creado correctamente

# %%
df_censo_2022_nacional.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  Periodo  \
# 0  Total Nacional                              NaN        NaN     2022
#
#       Total
# 0  47486727

# %%
df_censo_2022_autonomico.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  Periodo  \
# 0  Total Nacional                     01 Andalucía        NaN     2022
# 1  Total Nacional                        02 Aragón        NaN     2022
# 2  Total Nacional       03 Asturias, Principado de        NaN     2022
# 3  Total Nacional                04 Balears, Illes        NaN     2022
# 4  Total Nacional                      05 Canarias        NaN     2022
#
#      Total
# 0  8511167
# 1  1328215
# 2  1004960
# 3  1187043
# 4  2185607

# %%
df_censo_2022_provincial.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  Periodo  \
# 0  Total Nacional                     01 Andalucía   29 Málaga     2022
# 1  Total Nacional                     01 Andalucía     23 Jaén     2022
# 2  Total Nacional                     01 Andalucía  04 Almería     2022
# 3  Total Nacional                     01 Andalucía   21 Huelva     2022
# 4  Total Nacional                     01 Andalucía    11 Cádiz     2022
#
#      Total
# 0  1715109
# 1   624191
# 2   739541
# 3   531094
# 4  1250545

# %% [markdown]
# En primer lugar limpiamos los datos a nivel provincial

# %%
# Eliminamos la columna "Total Nacional" del DataFrame
df_censo_2022_provincial = df_censo_2022_provincial.drop(columns=["Total Nacional"])

# Mostramos las primeras filas del DataFrame actualizado
df_censo_2022_provincial.head()
# Out:
#   Comunidades y Ciudades Autónomas  Provincias  Periodo    Total
# 0                     01 Andalucía   29 Málaga     2022  1715109
# 1                     01 Andalucía     23 Jaén     2022   624191
# 2                     01 Andalucía  04 Almería     2022   739541
# 3                     01 Andalucía   21 Huelva     2022   531094
# 4                     01 Andalucía    11 Cádiz     2022  1250545

# %%
df_censo_2022_provincial.sample(20)
# Out:
#    Comunidades y Ciudades Autónomas           Provincias  Periodo    Total
# 47                    16 País Vasco       01 Araba/Álava     2022   333908
# 40                       12 Galicia         15 Coruña, A     2022  1119164
# 24               07 Castilla y León          34 Palencia     2022   157993
# 45   15 Navarra, Comunidad Foral de           31 Navarra     2022   664514
# 33                      09 Cataluña         43 Tarragona     2022   830906
# 26               07 Castilla y León            49 Zamora     2022   167868
# 6                      01 Andalucía           18 Granada     2022   926019
# 7                      01 Andalucía           14 Córdoba     2022   775110
# 49                     17 Rioja, La         26 Rioja, La     2022   319617
# 35          10 Comunitat Valenciana  03 Alicante/Alacant     2022  1907494
# 9                         02 Aragón            44 Teruel     2022   134132
# 48                    16 País Vasco          20 Gipuzkoa     2022   723241
# 31                      09 Cataluña            17 Girona     2022   790432
# 37                   11 Extremadura           10 Cáceres     2022   388957
# 29               07 Castilla y León              24 León     2022   449270
# 28               07 Castilla y León         37 Salamanca     2022   326285
# 11       03 Asturias, Principado de          33 Asturias     2022  1004960
# 10                        02 Aragón            22 Huesca     2022   225199
# 14                      05 Canarias       35 Palmas, Las     2022  1133733
# 0                      01 Andalucía            29 Málaga     2022  1715109

# %% [markdown]
# Procesamos el dataframe con la información provincial del censo

# %%
def procesar_nivel_educativo_provincias(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel provincial, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Elimina la columna "Total Nacional".
    2. Separa los códigos y nombres de comunidades y provincias en columnas distintas.
    3. Convierte las columnas 'Código comunidad' y 'Código provincia' a tipo int64.
    4. Reordena las columnas colocando los códigos y nombres de comunidades y provincias al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar la columna "Total Nacional"
    if "Total Nacional" in df.columns:
        df.drop(columns=["Total Nacional"], inplace=True)
           
    # 2. Separar código y nombre de comunidad y provincia
    if 'Comunidades y Ciudades Autónomas' in df.columns and 'Provincias' in df.columns:
        df[['Código comunidad', 'Nombre comunidad']] = df['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)
        df[['Código provincia', 'Nombre provincia']] = df['Provincias'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Comunidades y Ciudades Autónomas', 'Provincias'], inplace=True)

    # 3. Convertir las columnas 'Código comunidad' y 'Código provincia' a tipo int64 si existen
    for col in ['Código comunidad', 'Código provincia']:
        if col in df.columns:
            df[col] = df[col].astype('int64')
    
    # 4. Reordenar las columnas para que los códigos y nombres aparezcan primero
    columnas_prioritarias = ['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_censo_2022_provincial = procesar_nivel_educativo_provincias(df_censo_2022_provincial)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_censo_2022_provincial.info())
df_censo_2022_provincial.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código comunidad  52 non-null     int64
#  1   Nombre comunidad  52 non-null     object
#  2   Código provincia  52 non-null     int64
#  3   Nombre provincia  52 non-null     object
#  4   Periodo           52 non-null     int64
#  5   Total             52 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.6+ KB
# None
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                29           Málaga
# 1                 1        Andalucía                23             Jaén
# 2                 1        Andalucía                 4          Almería
# 3                 1        Andalucía                21           Huelva
# 4                 1        Andalucía                11            Cádiz
#
#    Periodo    Total
# 0     2022  1715109
# 1     2022   624191
# 2     2022   739541
# 3     2022   531094
# 4     2022  1250545

# %% [markdown]
# Elimanos la columna Periodo pues todos los datos son de 2022

# %%
# Eliminar la columna 'Periodo'
df_censo_2022_provincial.drop(columns=['Periodo'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_censo_2022_provincial.head()
# Out:
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                29           Málaga
# 1                 1        Andalucía                23             Jaén
# 2                 1        Andalucía                 4          Almería
# 3                 1        Andalucía                21           Huelva
# 4                 1        Andalucía                11            Cádiz
#
#      Total
# 0  1715109
# 1   624191
# 2   739541
# 3   531094
# 4  1250545

# %%
df_censo_2022_provincial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código comunidad  52 non-null     int64
#  1   Nombre comunidad  52 non-null     object
#  2   Código provincia  52 non-null     int64
#  3   Nombre provincia  52 non-null     object
#  4   Total             52 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df_censo_2022_municipios = pd.read_csv("datos/ine/censo_2022_municipios.csv", sep=';')

# %%
df_censo_2022_municipios.head()
# Out:
#    Total Nacional Provincias Municipios   Sexo              Edad  \
# 0  Total Nacional        NaN        NaN  Total  Todas las edades
# 1  Total Nacional        NaN        NaN  Total  Todas las edades
# 2  Total Nacional        NaN        NaN  Total  Todas las edades
# 3  Total Nacional        NaN        NaN  Total  Todas las edades
# 4  Total Nacional        NaN        NaN  Total  Todas las edades
#
#   Lugar de nacimiento  Periodo       Total
# 0               Total     2024  48.619.695
# 1               Total     2023  48.085.361
# 2               Total     2022  47.486.727
# 3               Total     2021  47.400.798
# 4              España     2024  39.781.461

# %%
df_censo_2022_municipios.sample(20)
# Out:
#          Total Nacional                 Provincias  \
# 5191134  Total Nacional               43 Tarragona
# 1169557  Total Nacional                  09 Burgos
# 1034119  Total Nacional                  09 Burgos
# 4755753  Total Nacional                 40 Segovia
# 615880   Total Nacional                 06 Badajoz
# 4557439  Total Nacional  38 Santa Cruz de Tenerife
# 3069702  Total Nacional                  25 Lleida
# 4168305  Total Nacional                34 Palencia
# 4473163  Total Nacional               37 Salamanca
# 2191086  Total Nacional                 18 Granada
# 6242143  Total Nacional                  49 Zamora
# 4320621  Total Nacional               37 Salamanca
# 5133849  Total Nacional               43 Tarragona
# 2265269  Total Nacional                 18 Granada
# 1294645  Total Nacional                 10 Cáceres
# 373093   Total Nacional                   05 Ávila
# 4802459  Total Nacional                 40 Segovia
# 2228727  Total Nacional                 18 Granada
# 5768313  Total Nacional       46 Valencia/València
# 5436554  Total Nacional                  45 Toledo
#
#                              Municipios     Sexo              Edad  \
# 5191134  43151 Torre de Fontaubella, La  Hombres   De 35 a 39 años
# 1169557              09390 Torresandino  Mujeres   De 10 a 14 años
# 1034119                  09159 Hontanas  Mujeres     De 5 a 9 años
# 4755753                 40118 Marazuela  Mujeres   De 15 a 19 años
# 615880       06141 Valencia del Ventoso  Hombres   De 90 a 94 años
# 4557439                38009 Breña Baja  Hombres  Todas las edades
# 3069702         25035 Sentiu de Sió, La  Mujeres   De 65 a 69 años
# 4168305    34225 Villamuriel de Cerrato    Total  Todas las edades
# 4473163               37282 Sanchotello  Mujeres   De 80 a 84 años
# 2191086                     18084 Gójar  Hombres   De 55 a 59 años
# 6242143         49269 Villaseco del Pan  Hombres   De 45 a 49 años
# 4320621                37080 Cantagallo    Total    100 y más años
# 5133849               43078 Masdenverge    Total   De 35 a 39 años
# 2265269             18906 Guájares, Los    Total   De 55 a 59 años
# 1294645                  10081 Gargüera  Hombres    100 y más años
# 373093              05097 Horcajada, La    Total   De 20 a 24 años
# 4802459      40184 San Pedro de Gaíllos  Mujeres     De 5 a 9 años
# 2228727                  18145 Ogíjares    Total   De 10 a 14 años
# 5768313                  46252 Vallanca    Total   De 65 a 69 años
# 5436554                 45038 Carranque  Hombres  Todas las edades
#
#         Lugar de nacimiento  Periodo  Total
# 5191134              España     2022    3.0
# 1169557               Total     2023   11.0
# 1034119              España     2021    0.0
# 4755753          Extranjera     2023    0.0
# 615880               España     2024     18
# 4557439              España     2021  2.451
# 3069702              España     2022   19.0
# 4168305          Extranjera     2023    468
# 4473163              España     2021    9.0
# 2191086              España     2022  230.0
# 6242143              España     2021    8.0
# 4320621          Extranjera     2023    0.0
# 5133849          Extranjera     2023   25.0
# 2265269              España     2023   85.0
# 1294645               Total     2023    0.0
# 373093                Total     2023   20.0
# 4802459          Extranjera     2021      0
# 2228727               Total     2021  954.0
# 5768313          Extranjera     2023    0.0
# 5436554               Total     2022  2.709

# %% [markdown]
# # Limpiamos y concatenamos los dataframes de nivel educativo de municipios pequeños y grandes

# %%
df_nivel_educativo_municipios_pequenios = pd.read_csv("datos/ine/nivel_educativo_municipios_pequenios.csv",sep=';')

# %%
df_nivel_educativo_municipios_pequenios.head()
# Out:
#       Municipios   Sexo                                Nivel de estudios  \
# 0  01006 Armiñón  Total                                            Total
# 1  01006 Armiñón  Total                                            Total
# 2  01006 Armiñón  Total                    Educación primaria e inferior
# 3  01006 Armiñón  Total                    Educación primaria e inferior
# 4  01006 Armiñón  Total  Primera etapa de educación secundaria y similar
#
#    Periodo  Total
# 0     2022    205
# 1     2021    198
# 2     2022     18
# 3     2021     17
# 4     2022     55

# %%
df_nivel_educativo_municipios_grandes = pd.read_csv("datos/ine/nivel_educativo_municipios_grandes.csv",sep=';')

# %%
df_nivel_educativo_municipios_grandes.sample(20)
# Out:
#                               Municipios     Sexo País de nacimiento  \
# 298802                  18029 Benamaurel    Total              Total
# 416935                  25093 Fondarella  Mujeres              Total
# 759368                     46227 Senyera    Total         Extranjera
# 235936                  14063 Valenzuela  Hombres             España
# 686648                 44068 Castelserás  Mujeres             España
# 709311                     45128 Pantoja  Hombres              Total
# 287310  17167 Sant Joan de les Abadesses    Total              Total
# 671033                43094 Móra la Nova    Total              Total
# 561762                     33074 Vegadeo    Total         Extranjera
# 803706  50025 Almunia de Doña Godina, La    Total         Extranjera
# 349865                  21031 Encinasola  Mujeres             España
# 627035                   40040 Cantalejo  Mujeres         Extranjera
# 432619          26026 Baños de Río Tobía  Mujeres             España
# 693874                   45018 Barcience  Hombres              Total
# 38953           03137 Vall de Laguar, la  Mujeres              Total
# 154098                     09125 Estépar    Total             España
# 223864                     13902 Ruidera  Hombres             España
# 357260                       21079 Zufre  Hombres              Total
# 631767                  40179 Sanchonuño  Mujeres              Total
# 76635          06091 Navalvillar de Pela    Total              Total
#
#                                         Nivel de estudios  Periodo  Total
# 298802                            Doctorado universitario     2022    6.0
# 416935  Enseñanzas de formación profesional, artes plá...     2021     49
# 759368  Grados universitarios de más de 240 créditos E...     2022    1.0
# 235936  Segunda etapa de educación secundaria, con ori...     2022   33.0
# 686648    Primera etapa de educación secundaria y similar     2022   91.0
# 709311  Segunda etapa de educación secundaria, con ori...     2021  126.0
# 287310  Enseñanzas de formación profesional, artes plá...     2022  267.0
# 671033  Segunda etapa de educación secundaria con orie...     2021  338.0
# 561762  Grados universitarios de hasta 240 créditos EC...     2022   17.0
# 803706                                       Sin estudios     2022  149.0
# 349865                            Doctorado universitario     2021    1.0
# 627035  Enseñanzas de formación profesional, artes plá...     2021    5.0
# 432619  Segunda etapa de educación secundaria con orie...     2021     55
# 693874  Grados universitarios de más de 240 créditos E...     2022   17.0
# 38953   Enseñanzas de formación profesional, artes plá...     2021     31
# 154098  Segunda etapa de educación secundaria con orie...     2022   48.0
# 223864  Grados universitarios de hasta 240 créditos EC...     2022    7.0
# 357260                                       Sin estudios     2022    9.0
# 631767  Grados universitarios de hasta 240 créditos EC...     2021   38.0
# 76635   Segunda etapa de educación secundaria, con ori...     2021    304

# %%
df_nivel_estudios_en_curso_por_lugar = pd.read_csv("datos/ine/nivel_estudios_en_curso_por_lugar.csv",sep=';')

# %%
df_nivel_estudios_en_curso_por_lugar.sample(20)
# Out:
#        Capitales y grandes ciudades     Sexo  \
# 69154                  25120 Lleida  Hombres
# 83178                 28074 Leganés  Hombres
# 44245    11020 Jerez de la Frontera  Mujeres
# 52233                 14021 Córdoba  Mujeres
# 15156                  06083 Mérida    Total
# 83590                 28074 Leganés  Mujeres
# 49605               12135 Vila-real    Total
# 898           01059 Vitoria-Gasteiz  Mujeres
# 73830                28007 Alcorcón    Total
# 106233                 30030 Murcia  Hombres
# 9802               03133 Torrevieja  Mujeres
# 105151       30027 Molina de Segura    Total
# 65206                    23050 Jaén  Mujeres
# 95053             29025 Benalmádena    Total
# 11673         04079 Roquetas de Mar  Hombres
# 4367                 03031 Benidorm    Total
# 103026              30016 Cartagena    Total
# 76882      28022 Boadilla del Monte    Total
# 46757            11031 San Fernando  Hombres
# 57728                 18087 Granada    Total
#
#        Relación entre lugar de residencia y lugar de estudios Nacionalidad  \
# 69154   Cursa estudios pero no hay información sobre e...       Extranjera
# 83178            Distinta provincia de la misma comunidad       Extranjera
# 44245                                  Distinta comunidad       Extranjera
# 52233            Distinta provincia de la misma comunidad            Total
# 15156                                               Total       Extranjera
# 83590   Cursa estudios pero no hay información sobre e...         Española
# 49605                                  Distinta comunidad         Española
# 898                                    Distinta comunidad       Extranjera
# 73830   Cursa estudios pero no hay información sobre e...            Total
# 106233                   Mismo municipio al de residencia            Total
# 9802                     Mismo municipio al de residencia            Total
# 105151                                  No cursa estudios         Española
# 65206                                               Total         Española
# 95053                                   No cursa estudios            Total
# 11673   Cursa estudios pero no hay información sobre e...            Total
# 4367                                    No cursa estudios       Extranjera
# 103026                                 Distinta comunidad         Española
# 76882   Cursa estudios pero no hay información sobre e...       Extranjera
# 46757                    Mismo municipio al de residencia            Total
# 57728   Cursa estudios pero no hay información sobre e...       Extranjera
#
#                                Nivel de estudios en curso  Periodo   Total
# 69154                       Educación primaria e inferior     2022       0
# 83178                                  Educación superior     2022       0
# 44245     Primera etapa de Educación Secundaria y similar     2021       1
# 52233   Segunda etapa de Educación Secundaria, con ori...     2021     110
# 15156     Primera etapa de Educación Secundaria y similar     2022      23
# 83590   Segunda etapa de educación secundaria, con ori...     2022      11
# 49605     Primera etapa de Educación Secundaria y similar     2021       0
# 898                         Educación primaria e inferior     2022       0
# 73830   Segunda etapa de educación secundaria, con ori...     2022      59
# 106233  Segunda etapa de Educación Secundaria, con ori...     2021   2.823
# 9802                                   Educación superior     2022      67
# 105151  Cursa estudios pero no hay información sobre l...     2021       0
# 65206   Segunda etapa de educación secundaria, con ori...     2022   1.771
# 95053                                   No cursa estudios     2021  54.137
# 11673   Segunda etapa de Educación Secundaria, con ori...     2021       4
# 4367    Cursa estudios pero no hay información sobre l...     2021       0
# 103026                      Educación primaria e inferior     2022       3
# 76882                       Educación primaria e inferior     2022       0
# 46757     Primera etapa de Educación Secundaria y similar     2021     347
# 57728                                               Total     2022     322

# %% [markdown]
# ## Limpiamos ahora  los datos de nivel educativo alcanzado por provincias.

# %%
df_nivel_educativo_provincias = pd.read_csv("datos/ine/nivel_educativo_provincias.csv", encoding= 'latin-1', sep=';')

# %%
df_nivel_educativo_provincias.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  \
# 0  Total Nacional                     01 Andalucía  04 Almería
# 1  Total Nacional                     01 Andalucía  04 Almería
# 2  Total Nacional                     01 Andalucía  04 Almería
# 3  Total Nacional                     01 Andalucía  04 Almería
# 4  Total Nacional                     01 Andalucía  04 Almería
#
#   País de nacimiento   Nivel de formación alcanzado     Sexo  Periodo    Total
# 0              Total                          Total    Total     2022  618.592
# 1              Total                          Total  Hombres     2022  315.700
# 2              Total                          Total  Mujeres     2022  302.892
# 3              Total  Educación primaria e inferior    Total     2022  164.692
# 4              Total  Educación primaria e inferior  Hombres     2022   86.587

# %%
# Eliminamos la columna "Total Nacional" del DataFrame
df_nivel_educativo_provincias = df_nivel_educativo_provincias.drop(columns=["Total Nacional"])

# Mostramos las primeras filas del DataFrame actualizado
df_nivel_educativo_provincias.head()
# Out:
#   Comunidades y Ciudades Autónomas  Provincias País de nacimiento  \
# 0                     01 Andalucía  04 Almería              Total
# 1                     01 Andalucía  04 Almería              Total
# 2                     01 Andalucía  04 Almería              Total
# 3                     01 Andalucía  04 Almería              Total
# 4                     01 Andalucía  04 Almería              Total
#
#     Nivel de formación alcanzado     Sexo  Periodo    Total
# 0                          Total    Total     2022  618.592
# 1                          Total  Hombres     2022  315.700
# 2                          Total  Mujeres     2022  302.892
# 3  Educación primaria e inferior    Total     2022  164.692
# 4  Educación primaria e inferior  Hombres     2022   86.587

# %% [markdown]
# Vamos a limpiar los nombres de las comunidades autonomas y las provinicas, generando columnas de codigo (numérico) para ambas a partir de los numeros que aparecen junto a ellas.

# %%
# Dividimos las columnas de comunidad y codigo de provincias y comunidades autonomas

# Separar código y nombre de comunidad autónoma
df_nivel_educativo_provincias[['Código comunidad', 'Nombre comunidad']] = \
    df_nivel_educativo_provincias['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)

# Separar código y nombre de provincia
df_nivel_educativo_provincias[['Código provincia', 'Nombre provincia']] = \
    df_nivel_educativo_provincias['Provincias'].str.split(pat=' ', n=1, expand=True)

# Eliminamos las columnas originales ya que han sido divididas
df_nivel_educativo_provincias = df_nivel_educativo_provincias.drop(columns=['Comunidades y Ciudades Autónomas', 'Provincias'])

# Mostramos las primeras filas del DataFrame actualizado
df_nivel_educativo_provincias.head()
# Out:
#   País de nacimiento   Nivel de formación alcanzado     Sexo  Periodo  \
# 0              Total                          Total    Total     2022
# 1              Total                          Total  Hombres     2022
# 2              Total                          Total  Mujeres     2022
# 3              Total  Educación primaria e inferior    Total     2022
# 4              Total  Educación primaria e inferior  Hombres     2022
#
#      Total Código comunidad Nombre comunidad Código provincia Nombre provincia
# 0  618.592               01        Andalucía               04          Almería
# 1  315.700               01        Andalucía               04          Almería
# 2  302.892               01        Andalucía               04          Almería
# 3  164.692               01        Andalucía               04          Almería
# 4   86.587               01        Andalucía               04          Almería

# %% [markdown]
# Formateamos las columnas "Total", "Código comunidad" y "Código provincia"

# %%
# Convertimos la columna "Total" a int64
df_nivel_educativo_provincias['Total'] = df_nivel_educativo_provincias['Total'].str.replace('.', '').astype('int64')

# Mostramos el DataFrame actualizado
df_nivel_educativo_provincias.head()
# Out:
#   País de nacimiento   Nivel de formación alcanzado     Sexo  Periodo   Total  \
# 0              Total                          Total    Total     2022  618592
# 1              Total                          Total  Hombres     2022  315700
# 2              Total                          Total  Mujeres     2022  302892
# 3              Total  Educación primaria e inferior    Total     2022  164692
# 4              Total  Educación primaria e inferior  Hombres     2022   86587
#
#   Código comunidad Nombre comunidad Código provincia Nombre provincia
# 0               01        Andalucía               04          Almería
# 1               01        Andalucía               04          Almería
# 2               01        Andalucía               04          Almería
# 3               01        Andalucía               04          Almería
# 4               01        Andalucía               04          Almería

# %%
# Convertir las columnas 'Código comunidad' y 'Código provincia' a tipo int64
df_nivel_educativo_provincias[ 'Código comunidad'] = df_nivel_educativo_provincias['Código comunidad'].astype('int64')
df_nivel_educativo_provincias['Código provincia'] = df_nivel_educativo_provincias['Código provincia'].astype('int64')

# %% [markdown]
# Pivotamos las columnas "País de nacimiento", "Nivel de formación alcanzado" y "Sexo" para tener toda la información de cada provincia en una sola fila. Dejamos fuera la columna Periodo, pues es siempre el 2022 y por tanto no aporta información relevante

# %%
# Pivotamos la columna "País de nacimiento" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_pais = df_nivel_educativo_provincias.pivot_table(
    index=['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia'],
    columns='País de nacimiento',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_pais.head()
# Out:
# País de nacimiento  Código comunidad Nombre comunidad  Código provincia  \
# 0                                  1        Andalucía                 4
# 1                                  1        Andalucía                11
# 2                                  1        Andalucía                14
# 3                                  1        Andalucía                18
# 4                                  1        Andalucía                21
#
# País de nacimiento Nombre provincia  Argentina  Bolivia  China  Colombia  \
# 0                           Almería      22836     4880   3784     21328
# 1                             Cádiz      10892     9744   7628     13840
# 2                           Córdoba       2796     1972   3416      8908
# 3                           Granada      20732    16844   7168     18380
# 4                            Huelva       2152     1816   2616      8456
#
# País de nacimiento  Cuba  Ecuador   España  Francia  Marruecos  \
# 0                   3112    27780  1837208    13496     205044
# 1                   4848     3696  3980088    12560      64768
# 2                   2056     7960  2549124     5156      15224
# 3                   4260     9396  2819328    16636      73360
# 4                   1968     4244  1586476     2540      64108
#
# País de nacimiento  Otros países de América  Otros países de Asia  \
# 0                                     16976                  8260
# 1                                     30644                  7884
# 2                                     18616                  3476
# 3                                     29676                  8372
# 4                                      9628                  1980
#
# País de nacimiento  Otros países de Europa  Otros países de Oceanía  \
# 0                                    66520                      312
# 1                                    49552                      776
# 2                                    17148                      296
# 3                                    54332                      572
# 4                                    38248                       92
#
# País de nacimiento  Otros países de África   Perú  Reino Unido  \
# 0                                    73992  11324        65544
# 1                                    12124   5168        28136
# 2                                     6112   1960         4348
# 3                                    20576   4088        25636
# 4                                    21540   1680         4536
#
# País de nacimiento  República Dominicana  Rumanía    Total  Ucrania  Venezuela
# 0                                   3908    75224  2474368     5916       6924
# 1                                   5000     8716  4266756     2804       7888
# 2                                   1496    16380  2672472     1820       4208
# 3                                   4232    28420  3174912     2416      10488
# 4                                   1372    52520  1813056     3512       3572

# %%
# Pivotamos la columna "Nivel de formación alcanzado" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_nivel = df_nivel_educativo_provincias.pivot_table(
    index=['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia'],
    columns='Nivel de formación alcanzado',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_nivel.head()
# Out:
# Nivel de formación alcanzado  Código comunidad Nombre comunidad  \
# 0                                            1        Andalucía
# 1                                            1        Andalucía
# 2                                            1        Andalucía
# 3                                            1        Andalucía
# 4                                            1        Andalucía
#
# Nivel de formación alcanzado  Código provincia Nombre provincia  \
# 0                                            4          Almería
# 1                                           11            Cádiz
# 2                                           14          Córdoba
# 3                                           18          Granada
# 4                                           21           Huelva
#
# Nivel de formación alcanzado  Educación primaria e inferior  \
# 0                                                    658768
# 1                                                    743224
# 2                                                    485528
# 3                                                    525080
# 4                                                    342592
#
# Nivel de formación alcanzado  Educación superior  \
# 0                                         568804
# 1                                        1120036
# 2                                         737780
# 3                                         976448
# 4                                         444416
#
# Nivel de formación alcanzado  Primera etapa de educación secundaria y similar  \
# 0                                                                      818604
# 1                                                                     1516532
# 2                                                                      944780
# 3                                                                     1064516
# 4                                                                      714704
#
# Nivel de formación alcanzado  Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                                                        428192
# 1                                                                        886964
# 2                                                                        504384
# 3                                                                        608868
# 4                                                                        311344
#
# Nivel de formación alcanzado    Total
# 0                             2474368
# 1                             4266756
# 2                             2672472
# 3                             3174912
# 4                             1813056

# %%
# Pivotamos la columna "Sexo" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_sexo = df_nivel_educativo_provincias.pivot_table(
    index=['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia'],
    columns='Sexo',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_sexo.head()
# Out:
# Sexo  Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                    1        Andalucía                 4          Almería
# 1                    1        Andalucía                11            Cádiz
# 2                    1        Andalucía                14          Córdoba
# 3                    1        Andalucía                18          Granada
# 4                    1        Andalucía                21           Huelva
#
# Sexo  Hombres  Mujeres    Total
# 0     1262800  1211568  2474368
# 1     2088800  2177956  4266756
# 2     1298348  1374124  2672472
# 3     1554956  1619956  3174912
# 4      892656   920400  1813056

# %%
 # Concatenamos los tres DataFrames generados con outer join
df_concatenado = pd.merge(
    pd.merge(
        df_nivel_educativo_pivotado_pais, 
        df_nivel_educativo_pivotado_nivel, 
        on=['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia'], 
        how='outer'
    ), 
    df_nivel_educativo_pivotado_sexo, 
    on=['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia'], 
    how='outer'
)

# Mostramos las primeras filas del DataFrame concatenado
df_concatenado.head()
# Out:
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                 4          Almería
# 1                 1        Andalucía                11            Cádiz
# 2                 1        Andalucía                14          Córdoba
# 3                 1        Andalucía                18          Granada
# 4                 1        Andalucía                21           Huelva
#
#    Argentina  Bolivia  China  Colombia  Cuba  Ecuador   España  Francia  \
# 0      22836     4880   3784     21328  3112    27780  1837208    13496
# 1      10892     9744   7628     13840  4848     3696  3980088    12560
# 2       2796     1972   3416      8908  2056     7960  2549124     5156
# 3      20732    16844   7168     18380  4260     9396  2819328    16636
# 4       2152     1816   2616      8456  1968     4244  1586476     2540
#
#    Marruecos  Otros países de América  Otros países de Asia  \
# 0     205044                    16976                  8260
# 1      64768                    30644                  7884
# 2      15224                    18616                  3476
# 3      73360                    29676                  8372
# 4      64108                     9628                  1980
#
#    Otros países de Europa  Otros países de Oceanía  Otros países de África  \
# 0                   66520                      312                   73992
# 1                   49552                      776                   12124
# 2                   17148                      296                    6112
# 3                   54332                      572                   20576
# 4                   38248                       92                   21540
#
#     Perú  Reino Unido  República Dominicana  Rumanía  Total_x  Ucrania  \
# 0  11324        65544                  3908    75224  2474368     5916
# 1   5168        28136                  5000     8716  4266756     2804
# 2   1960         4348                  1496    16380  2672472     1820
# 3   4088        25636                  4232    28420  3174912     2416
# 4   1680         4536                  1372    52520  1813056     3512
#
#    Venezuela  Educación primaria e inferior  Educación superior  \
# 0       6924                         658768              568804
# 1       7888                         743224             1120036
# 2       4208                         485528              737780
# 3      10488                         525080              976448
# 4       3572                         342592              444416
#
#    Primera etapa de educación secundaria y similar  \
# 0                                           818604
# 1                                          1516532
# 2                                           944780
# 3                                          1064516
# 4                                           714704
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                             428192
# 1                                             886964
# 2                                             504384
# 3                                             608868
# 4                                             311344
#
#    Total_y  Hombres  Mujeres    Total
# 0  2474368  1262800  1211568  2474368
# 1  4266756  2088800  2177956  4266756
# 2  2672472  1298348  1374124  2672472
# 3  3174912  1554956  1619956  3174912
# 4  1813056   892656   920400  1813056

# %% [markdown]
# "Total_x" y "Total_y" son duplciados de la columna "Total" así que los eliminamos

# %%
# Eliminamos las columnas "Total_x" y "Total_y" ya que han sido divididas
df_concatenado = df_concatenado.drop(columns=["Total_x", "Total_y"])
df_concatenado.head()
# Out:
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                 4          Almería
# 1                 1        Andalucía                11            Cádiz
# 2                 1        Andalucía                14          Córdoba
# 3                 1        Andalucía                18          Granada
# 4                 1        Andalucía                21           Huelva
#
#    Argentina  Bolivia  China  Colombia  Cuba  Ecuador   España  Francia  \
# 0      22836     4880   3784     21328  3112    27780  1837208    13496
# 1      10892     9744   7628     13840  4848     3696  3980088    12560
# 2       2796     1972   3416      8908  2056     7960  2549124     5156
# 3      20732    16844   7168     18380  4260     9396  2819328    16636
# 4       2152     1816   2616      8456  1968     4244  1586476     2540
#
#    Marruecos  Otros países de América  Otros países de Asia  \
# 0     205044                    16976                  8260
# 1      64768                    30644                  7884
# 2      15224                    18616                  3476
# 3      73360                    29676                  8372
# 4      64108                     9628                  1980
#
#    Otros países de Europa  Otros países de Oceanía  Otros países de África  \
# 0                   66520                      312                   73992
# 1                   49552                      776                   12124
# 2                   17148                      296                    6112
# 3                   54332                      572                   20576
# 4                   38248                       92                   21540
#
#     Perú  Reino Unido  República Dominicana  Rumanía  Ucrania  Venezuela  \
# 0  11324        65544                  3908    75224     5916       6924
# 1   5168        28136                  5000     8716     2804       7888
# 2   1960         4348                  1496    16380     1820       4208
# 3   4088        25636                  4232    28420     2416      10488
# 4   1680         4536                  1372    52520     3512       3572
#
#    Educación primaria e inferior  Educación superior  \
# 0                         658768              568804
# 1                         743224             1120036
# 2                         485528              737780
# 3                         525080              976448
# 4                         342592              444416
#
#    Primera etapa de educación secundaria y similar  \
# 0                                           818604
# 1                                          1516532
# 2                                           944780
# 3                                          1064516
# 4                                           714704
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                             428192
# 1                                             886964
# 2                                             504384
# 3                                             608868
# 4                                             311344
#
#    Hombres  Mujeres    Total
# 0  1262800  1211568  2474368
# 1  2088800  2177956  4266756
# 2  1298348  1374124  2672472
# 3  1554956  1619956  3174912
# 4   892656   920400  1813056

# %%
#Renombramos el dataframe para mayor claridad
df_nivel_educativo_provincias=df_concatenado

# %%
df_nivel_educativo_provincias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 31 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Código comunidad                                                              52 non-null     int64
#  1   Nombre comunidad                                                              52 non-null     object
#  2   Código provincia                                                              52 non-null     int64
#  3   Nombre provincia                                                              52 non-null     object
#  4   Argentina                                                                     52 non-null     int64
#  5   Bolivia                                                                       52 non-null     int64
#  6   China                                                                         52 non-null     int64
#  7   Colombia                                                                      52 non-null     int64
#  8   Cuba                                                                          52 non-null     int64
#  9   Ecuador                                                                       52 non-null     int64
#  10  España                                                                        52 non-null     int64
#  11  Francia                                                                       52 non-null     int64
#  12  Marruecos                                                                     52 non-null     int64
#  13  Otros países de América                                                       52 non-null     int64
#  14  Otros países de Asia                                                          52 non-null     int64
#  15  Otros países de Europa                                                        52 non-null     int64
#  16  Otros países de Oceanía                                                       52 non-null     int64
#  17  Otros países de África                                                        52 non-null     int64
#  18  Perú                                                                          52 non-null     int64
#  19  Reino Unido                                                                   52 non-null     int64
#  20  República Dominicana                                                          52 non-null     int64
#  21  Rumanía                                                                       52 non-null     int64
#  22  Ucrania                                                                       52 non-null     int64
#  23  Venezuela                                                                     52 non-null     int64
#  24  Educación primaria e inferior                                                 52 non-null     int64
#  25  Educación superior                                                            52 non-null     int64
#  26  Primera etapa de educación secundaria y similar                               52 non-null     int64
#  27  Segunda etapa de educación secundaria y educación postsecundaria no superior  52 non-null     int64
#  28  Hombres                                                                       52 non-null     int64
#  29  Mujeres                                                                       52 non-null     int64
#  30  Total                                                                         52 non-null     int64
# dtypes: int64(29), object(2)
# memory usage: 12.7+ KB

# %%
df_nivel_educativo_provincias["Nombre provincia"].unique()
# Out:
# array(['Almería', 'Cádiz', 'Córdoba', 'Granada', 'Huelva', 'Jaén',
#        'Málaga', 'Sevilla', 'Huesca', 'Teruel', 'Zaragoza', 'Asturias',
#        'Balears, Illes', 'Palmas, Las', 'Santa Cruz de Tenerife',
#        'Cantabria', 'Ávila', 'Burgos', 'León', 'Palencia', 'Salamanca',
#        'Segovia', 'Soria', 'Valladolid', 'Zamora', 'Albacete',
#        'Ciudad Real', 'Cuenca', 'Guadalajara', 'Toledo', 'Barcelona',
#        'Girona', 'Lleida', 'Tarragona', 'Alicante/Alacant',
#        'Castellón/Castelló', 'Valencia/València', 'Badajoz', 'Cáceres',
#        'Coruña, A', 'Lugo', 'Ourense', 'Pontevedra', 'Madrid', 'Murcia',
#        'Navarra', 'Araba/Álava', 'Gipuzkoa', 'Bizkaia', 'Rioja, La',
#        'Ceuta', 'Melilla'], dtype=object)

# %%
df_nivel_educativo_provincias["Nombre comunidad"].unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias, Principado de', 'Balears, Illes',
#        'Canarias', 'Cantabria', 'Castilla y León', 'Castilla - La Mancha',
#        'Cataluña', 'Comunitat Valenciana', 'Extremadura', 'Galicia',
#        'Madrid, Comunidad de', 'Murcia, Región de',
#        'Navarra, Comunidad Foral de', 'País Vasco', 'Rioja, La', 'Ceuta',
#        'Melilla'], dtype=object)

# %% [markdown]
# Ceuta y Melilla son ciudades autónomas. Las analizaremos junto con las Comunidades autónomas

# %%
# Reordenar las columnas para que 'Hombres' y 'Mujeres' aparezcan después de 'Nombre provincia'
columnas_reordenadas = (
    ['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia', 'Hombres', 'Mujeres'] +
    [col for col in df_nivel_educativo_provincias.columns if col not in ['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia', 'Hombres', 'Mujeres']]
)

df_nivel_educativo_provincias = df_nivel_educativo_provincias[columnas_reordenadas]

# Mostrar las primeras filas del DataFrame reordenado
df_nivel_educativo_provincias.head()
# Out:
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                 4          Almería
# 1                 1        Andalucía                11            Cádiz
# 2                 1        Andalucía                14          Córdoba
# 3                 1        Andalucía                18          Granada
# 4                 1        Andalucía                21           Huelva
#
#    Hombres  Mujeres  Argentina  Bolivia  China  Colombia  Cuba  Ecuador  \
# 0  1262800  1211568      22836     4880   3784     21328  3112    27780
# 1  2088800  2177956      10892     9744   7628     13840  4848     3696
# 2  1298348  1374124       2796     1972   3416      8908  2056     7960
# 3  1554956  1619956      20732    16844   7168     18380  4260     9396
# 4   892656   920400       2152     1816   2616      8456  1968     4244
#
#     España  Francia  Marruecos  Otros países de América  Otros países de Asia  \
# 0  1837208    13496     205044                    16976                  8260
# 1  3980088    12560      64768                    30644                  7884
# 2  2549124     5156      15224                    18616                  3476
# 3  2819328    16636      73360                    29676                  8372
# 4  1586476     2540      64108                     9628                  1980
#
#    Otros países de Europa  Otros países de Oceanía  Otros países de África  \
# 0                   66520                      312                   73992
# 1                   49552                      776                   12124
# 2                   17148                      296                    6112
# 3                   54332                      572                   20576
# 4                   38248                       92                   21540
#
#     Perú  Reino Unido  República Dominicana  Rumanía  Ucrania  Venezuela  \
# 0  11324        65544                  3908    75224     5916       6924
# 1   5168        28136                  5000     8716     2804       7888
# 2   1960         4348                  1496    16380     1820       4208
# 3   4088        25636                  4232    28420     2416      10488
# 4   1680         4536                  1372    52520     3512       3572
#
#    Educación primaria e inferior  Educación superior  \
# 0                         658768              568804
# 1                         743224             1120036
# 2                         485528              737780
# 3                         525080              976448
# 4                         342592              444416
#
#    Primera etapa de educación secundaria y similar  \
# 0                                           818604
# 1                                          1516532
# 2                                           944780
# 3                                          1064516
# 4                                           714704
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                             428192
# 1                                             886964
# 2                                             504384
# 3                                             608868
# 4                                             311344
#
#      Total
# 0  2474368
# 1  4266756
# 2  2672472
# 3  3174912
# 4  1813056

# %%
# Crear una lista de categorías para las columnas del DataFrame
categorias = (
    ['Comunidades ciudades autónomas'] * 2 +  # Código comunidad, Nombre comunidad
    ['Provincias'] * 2 +  # Código provincia, Nombre provincia
    ['Sexo'] * 2 +  # Hombres, Mujeres
    ['País de nacimiento'] * 20 +  # Países de nacimiento
    ['Nivel educativo'] * 4 +  # Niveles educativos
    ['Población mayor de 15 años']  # Total
)

# Asignar las categorías a las columnas del DataFrame
df_nivel_educativo_provincias.columns = pd.MultiIndex.from_tuples(zip(categorias, df_nivel_educativo_provincias.columns))
df_nivel_educativo_provincias.head()
# Out:
#   Comunidades ciudades autónomas                        Provincias  \
#                 Código comunidad Nombre comunidad Código provincia
# 0                              1        Andalucía                4
# 1                              1        Andalucía               11
# 2                              1        Andalucía               14
# 3                              1        Andalucía               18
# 4                              1        Andalucía               21
#
#                        Sexo          País de nacimiento                \
#   Nombre provincia  Hombres  Mujeres          Argentina Bolivia China
# 0          Almería  1262800  1211568              22836    4880  3784
# 1            Cádiz  2088800  2177956              10892    9744  7628
# 2          Córdoba  1298348  1374124               2796    1972  3416
# 3          Granada  1554956  1619956              20732   16844  7168
# 4           Huelva   892656   920400               2152    1816  2616
#
#                                                                              \
#   Colombia  Cuba Ecuador   España Francia Marruecos Otros países de América
# 0    21328  3112   27780  1837208   13496    205044                   16976
# 1    13840  4848    3696  3980088   12560     64768                   30644
# 2     8908  2056    7960  2549124    5156     15224                   18616
# 3    18380  4260    9396  2819328   16636     73360                   29676
# 4     8456  1968    4244  1586476    2540     64108                    9628
#
#                                                                        \
#   Otros países de Asia Otros países de Europa Otros países de Oceanía
# 0                 8260                  66520                     312
# 1                 7884                  49552                     776
# 2                 3476                  17148                     296
# 3                 8372                  54332                     572
# 4                 1980                  38248                      92
#
#                                                                           \
#   Otros países de África   Perú Reino Unido República Dominicana Rumanía
# 0                  73992  11324       65544                 3908   75224
# 1                  12124   5168       28136                 5000    8716
# 2                   6112   1960        4348                 1496   16380
# 3                  20576   4088       25636                 4232   28420
# 4                  21540   1680        4536                 1372   52520
#
#                                   Nivel educativo                     \
#   Ucrania Venezuela Educación primaria e inferior Educación superior
# 0    5916      6924                        658768             568804
# 1    2804      7888                        743224            1120036
# 2    1820      4208                        485528             737780
# 3    2416     10488                        525080             976448
# 4    3512      3572                        342592             444416
#
#                                                    \
#   Primera etapa de educación secundaria y similar
# 0                                          818604
# 1                                         1516532
# 2                                          944780
# 3                                         1064516
# 4                                          714704
#
#                                                                                 \
#   Segunda etapa de educación secundaria y educación postsecundaria no superior
# 0                                             428192
# 1                                             886964
# 2                                             504384
# 3                                             608868
# 4                                             311344
#
#   Población mayor de 15 años
#                        Total
# 0                    2474368
# 1                    4266756
# 2                    2672472
# 3                    3174912
# 4                    1813056

# %%
df_nivel_educativo_provincias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 31 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   (Comunidades ciudades autónomas, Código comunidad)                                               52 non-null     int64
#  1   (Comunidades ciudades autónomas, Nombre comunidad)                                               52 non-null     object
#  2   (Provincias, Código provincia)                                                                   52 non-null     int64
#  3   (Provincias, Nombre provincia)                                                                   52 non-null     object
#  4   (Sexo, Hombres)                                                                                  52 non-null     int64
#  5   (Sexo, Mujeres)                                                                                  52 non-null     int64
#  6   (País de nacimiento, Argentina)                                                                  52 non-null     int64
#  7   (País de nacimiento, Bolivia)                                                                    52 non-null     int64
#  8   (País de nacimiento, China)                                                                      52 non-null     int64
#  9   (País de nacimiento, Colombia)                                                                   52 non-null     int64
#  10  (País de nacimiento, Cuba)                                                                       52 non-null     int64
#  11  (País de nacimiento, Ecuador)                                                                    52 non-null     int64
#  12  (País de nacimiento, España)                                                                     52 non-null     int64
#  13  (País de nacimiento, Francia)                                                                    52 non-null     int64
#  14  (País de nacimiento, Marruecos)                                                                  52 non-null     int64
#  15  (País de nacimiento, Otros países de América)                                                    52 non-null     int64
#  16  (País de nacimiento, Otros países de Asia)                                                       52 non-null     int64
#  17  (País de nacimiento, Otros países de Europa)                                                     52 non-null     int64
#  18  (País de nacimiento, Otros países de Oceanía)                                                    52 non-null     int64
#  19  (País de nacimiento, Otros países de África)                                                     52 non-null     int64
#  20  (País de nacimiento, Perú)                                                                       52 non-null     int64
#  21  (País de nacimiento, Reino Unido)                                                                52 non-null     int64
#  22  (País de nacimiento, República Dominicana)                                                       52 non-null     int64
#  23  (País de nacimiento, Rumanía)                                                                    52 non-null     int64
#  24  (País de nacimiento, Ucrania)                                                                    52 non-null     int64
#  25  (País de nacimiento, Venezuela)                                                                  52 non-null     int64
#  26  (Nivel educativo, Educación primaria e inferior)                                                 52 non-null     int64
#  27  (Nivel educativo, Educación superior)                                                            52 non-null     int64
#  28  (Nivel educativo, Primera etapa de educación secundaria y similar)                               52 non-null     int64
#  29  (Nivel educativo, Segunda etapa de educación secundaria y educación postsecundaria no superior)  52 non-null     int64
#  30  (Población mayor de 15 años, Total)                                                              52 non-null     int64
# dtypes: int64(29), object(2)
# memory usage: 12.7+ KB

# %%
# Guardamos el DataFrame en un archivo CSV
df_nivel_educativo_provincias.to_csv("datos_limpiados/provincias/nivel_educativo_provincias_limpio.csv", index=False)

# %% [markdown]
# ## Limpiamos ahora los datos de nivel educativo alcanzado por comunidades autónomas

# %%
df_nivel_educativo_comunidades = pd.read_csv("datos/ine/nivel_educativo_comunidades.csv", encoding= 'latin-1', sep=';')

# %%
df_nivel_educativo_comunidades.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  \
# 0  Total Nacional                     01 Andalucía         NaN
# 1  Total Nacional                     01 Andalucía         NaN
# 2  Total Nacional                     01 Andalucía         NaN
# 3  Total Nacional                     01 Andalucía         NaN
# 4  Total Nacional                     01 Andalucía         NaN
#
#   País de nacimiento   Nivel de formación alcanzado     Sexo  Periodo  \
# 0              Total                          Total    Total     2022
# 1              Total                          Total  Hombres     2022
# 2              Total                          Total  Mujeres     2022
# 3              Total  Educación primaria e inferior    Total     2022
# 4              Total  Educación primaria e inferior  Hombres     2022
#
#        Total
# 0  7.251.427
# 1  3.547.880
# 2  3.703.547
# 3  1.332.260
# 4    583.687

# %% [markdown]
# La columna 'Provincias' está vacía así que la eliminaos

# %%
# Eliminar la columna 'Provincias'
df_nivel_educativo_comunidades.drop(columns=['Provincias'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_nivel_educativo_comunidades.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas País de nacimiento  \
# 0  Total Nacional                     01 Andalucía              Total
# 1  Total Nacional                     01 Andalucía              Total
# 2  Total Nacional                     01 Andalucía              Total
# 3  Total Nacional                     01 Andalucía              Total
# 4  Total Nacional                     01 Andalucía              Total
#
#     Nivel de formación alcanzado     Sexo  Periodo      Total
# 0                          Total    Total     2022  7.251.427
# 1                          Total  Hombres     2022  3.547.880
# 2                          Total  Mujeres     2022  3.703.547
# 3  Educación primaria e inferior    Total     2022  1.332.260
# 4  Educación primaria e inferior  Hombres     2022    583.687

# %%
# Eliminamos la columna "Total Nacional" del DataFrame
df_nivel_educativo_comunidades = df_nivel_educativo_comunidades.drop(columns=["Total Nacional"])
# Mostramos las primeras filas del DataFrame actualizado
df_nivel_educativo_comunidades.head()
# Out:
#   Comunidades y Ciudades Autónomas País de nacimiento  \
# 0                     01 Andalucía              Total
# 1                     01 Andalucía              Total
# 2                     01 Andalucía              Total
# 3                     01 Andalucía              Total
# 4                     01 Andalucía              Total
#
#     Nivel de formación alcanzado     Sexo  Periodo      Total
# 0                          Total    Total     2022  7.251.427
# 1                          Total  Hombres     2022  3.547.880
# 2                          Total  Mujeres     2022  3.703.547
# 3  Educación primaria e inferior    Total     2022  1.332.260
# 4  Educación primaria e inferior  Hombres     2022    583.687

# %% [markdown]
# Vamos a limpiar los nombres de las comunidades y ciudades autonomas, generando columnas de codigo (numérico) para ambas a partir de los numeros que aparecen junto a ellas.

# %%
# Dividimos la columna de comunidad y codigo de comunidades y ciduades autonomas

# Separar código y nombre de comunidad autónoma
df_nivel_educativo_comunidades[['Código comunidad', 'Nombre comunidad']] = \
    df_nivel_educativo_comunidades['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)


# Eliminamos la columna original que ya ha sido divididas
df_nivel_educativo_comunidades = df_nivel_educativo_comunidades.drop(columns=['Comunidades y Ciudades Autónomas'])

# Mostramos las primeras filas del DataFrame actualizado
df_nivel_educativo_comunidades.head()
# Out:
#   País de nacimiento   Nivel de formación alcanzado     Sexo  Periodo  \
# 0              Total                          Total    Total     2022
# 1              Total                          Total  Hombres     2022
# 2              Total                          Total  Mujeres     2022
# 3              Total  Educación primaria e inferior    Total     2022
# 4              Total  Educación primaria e inferior  Hombres     2022
#
#        Total Código comunidad Nombre comunidad
# 0  7.251.427               01        Andalucía
# 1  3.547.880               01        Andalucía
# 2  3.703.547               01        Andalucía
# 3  1.332.260               01        Andalucía
# 4    583.687               01        Andalucía

# %% [markdown]
# Ordenamos las columnas para que las columnas que contienen el código y el nombre de la comunidad estén al principio del dataframe

# %%
# Reordenamos las columnas para que las cuatro columnas indicadas sean las primeras
columnas_ordenadas = [
    'Código comunidad', 'Nombre comunidad', 
] + [col for col in df_nivel_educativo_comunidades.columns if col not in [
    'Código comunidad', 'Nombre comunidad'
]]

df_nivel_educativo_comunidades = df_nivel_educativo_comunidades[columnas_ordenadas]

# Mostramos el DataFrame reordenado
df_nivel_educativo_comunidades.head()
# Out:
#   Código comunidad Nombre comunidad País de nacimiento  \
# 0               01        Andalucía              Total
# 1               01        Andalucía              Total
# 2               01        Andalucía              Total
# 3               01        Andalucía              Total
# 4               01        Andalucía              Total
#
#     Nivel de formación alcanzado     Sexo  Periodo      Total
# 0                          Total    Total     2022  7.251.427
# 1                          Total  Hombres     2022  3.547.880
# 2                          Total  Mujeres     2022  3.703.547
# 3  Educación primaria e inferior    Total     2022  1.332.260
# 4  Educación primaria e inferior  Hombres     2022    583.687

# %% [markdown]
# Formateamos la columna "Total" y la columna "Código comunidad"

# %%
# Convertimos la columna "Total" a int64
df_nivel_educativo_comunidades['Total'] = df_nivel_educativo_comunidades['Total'].str.replace('.', '').astype('int64')

# %%
# Convertir la columna 'Código comunidad' a tipo int64
df_nivel_educativo_comunidades[ 'Código comunidad'] = df_nivel_educativo_comunidades['Código comunidad'].astype('int64')

# %% [markdown]
# Pivotamos las columnas "País de nacimiento", "Nivel de formación alcanzado" y "Sexo" para tener toda la información de cada Comunidad en una sola fila. Dejamos fuera la columna Periodo, pues es siempre el 2022 y por tanto no aporta información relevante

# %%
# Pivotamos la columna "País de nacimiento" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_pais = df_nivel_educativo_comunidades.pivot_table(
    index=['Código comunidad', 'Nombre comunidad'],
    columns='País de nacimiento',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_pais.head()
# Out:
# País de nacimiento  Código comunidad         Nombre comunidad  Argentina  \
# 0                                  1                Andalucía     179896
# 1                                  2                   Aragón      16420
# 2                                  3  Asturias, Principado de      17804
# 3                                  4           Balears, Illes     109768
# 4                                  5                 Canarias      71592
#
# País de nacimiento  Bolivia  China  Colombia    Cuba  Ecuador    España  \
# 0                     68788  70360    168684   44220    95272  25504212
# 1                      4852  19048     56884   14292    50548   3830992
# 2                      2264   4812     27380   18996    18680   3280668
# 3                     27656  19624     92660   27096    62752   2939664
# 4                     15352  34976    136776  181500    26268   5980416
#
# País de nacimiento  Francia  Marruecos  Otros países de América  \
# 0                    109364     694492                   309596
# 1                     15676      86312                    89092
# 2                      9356      14500                    51244
# 3                     33368     107764                   114968
# 4                     27628     100384                    98672
#
# País de nacimiento  Otros países de Asia  Otros países de Europa  \
# 0                                  97952                  608596
# 1                                  18628                   61128
# 2                                   5660                   53372
# 3                                  43276                  245684
# 4                                  51412                  429960
#
# País de nacimiento  Otros países de Oceanía  Otros países de África   Perú  \
# 0                                      5084                  204624  53628
# 1                                       632                   87656  17924
# 2                                       920                   15244   6948
# 3                                      2108                   54416  19192
# 4                                      1232                   61376  17872
#
# País de nacimiento  Reino Unido  República Dominicana  Rumanía     Total  \
# 0                        340296                 34140   254560  29005708
# 1                          4520                 21072   166692   4594760
# 2                          4756                 18116    22772   3602696
# 3                         72096                 20548    41612   4066804
# 4                        113688                 18760    29468   7675432
#
# País de nacimiento  Ucrania  Venezuela
# 0                     65968      95976
# 1                      9272      23120
# 2                      3412      25792
# 3                      8608      23944
# 4                      6412     271688

# %%
# Pivotamos la columna "Nivel de formación alcanzado" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_nivel = df_nivel_educativo_comunidades.pivot_table(
    index=['Código comunidad', 'Nombre comunidad'],
    columns='Nivel de formación alcanzado',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_nivel.head()
# Out:
# Nivel de formación alcanzado  Código comunidad         Nombre comunidad  \
# 0                                            1                Andalucía
# 1                                            2                   Aragón
# 2                                            3  Asturias, Principado de
# 3                                            4           Balears, Illes
# 4                                            5                 Canarias
#
# Nivel de formación alcanzado  Educación primaria e inferior  \
# 0                                                   5329040
# 1                                                    677896
# 2                                                    556792
# 3                                                    551496
# 4                                                   1403748
#
# Nivel de formación alcanzado  Educación superior  \
# 0                                        7889300
# 1                                        1516724
# 2                                        1210520
# 3                                        1146044
# 4                                        2200628
#
# Nivel de formación alcanzado  Primera etapa de educación secundaria y similar  \
# 0                                                                    10066364
# 1                                                                     1391740
# 2                                                                     1035988
# 3                                                                     1295332
# 4                                                                     2267688
#
# Nivel de formación alcanzado  Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                                                       5721004
# 1                                                                       1008400
# 2                                                                        799396
# 3                                                                       1073932
# 4                                                                       1803368
#
# Nivel de formación alcanzado     Total
# 0                             29005708
# 1                              4594760
# 2                              3602696
# 3                              4066804
# 4                              7675432

# %%
# Pivotamos la columna "Sexo" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_sexo = df_nivel_educativo_comunidades.pivot_table(
    index=['Código comunidad', 'Nombre comunidad'],
    columns='Sexo',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_sexo.head()
# Out:
# Sexo  Código comunidad         Nombre comunidad   Hombres   Mujeres     Total
# 0                    1                Andalucía  14191520  14814188  29005708
# 1                    2                   Aragón   2257748   2337012   4594760
# 2                    3  Asturias, Principado de   1703944   1898752   3602696
# 3                    4           Balears, Illes   2017116   2049688   4066804
# 4                    5                 Canarias   3773072   3902360   7675432

# %%
 # Concatenamos los tres DataFrames generados con outer join
df_concatenado = pd.merge(
    pd.merge(
        df_nivel_educativo_pivotado_pais, 
        df_nivel_educativo_pivotado_nivel, 
        on=['Código comunidad', 'Nombre comunidad'], 
        how='outer'
    ), 
    df_nivel_educativo_pivotado_sexo, 
    on=['Código comunidad', 'Nombre comunidad'], 
    how='outer'
)

# Mostramos las primeras filas del DataFrame concatenado
df_concatenado.head()
# Out:
#    Código comunidad         Nombre comunidad  Argentina  Bolivia  China  \
# 0                 1                Andalucía     179896    68788  70360
# 1                 2                   Aragón      16420     4852  19048
# 2                 3  Asturias, Principado de      17804     2264   4812
# 3                 4           Balears, Illes     109768    27656  19624
# 4                 5                 Canarias      71592    15352  34976
#
#    Colombia    Cuba  Ecuador    España  Francia  Marruecos  \
# 0    168684   44220    95272  25504212   109364     694492
# 1     56884   14292    50548   3830992    15676      86312
# 2     27380   18996    18680   3280668     9356      14500
# 3     92660   27096    62752   2939664    33368     107764
# 4    136776  181500    26268   5980416    27628     100384
#
#    Otros países de América  Otros países de Asia  Otros países de Europa  \
# 0                   309596                 97952                  608596
# 1                    89092                 18628                   61128
# 2                    51244                  5660                   53372
# 3                   114968                 43276                  245684
# 4                    98672                 51412                  429960
#
#    Otros países de Oceanía  Otros países de África   Perú  Reino Unido  \
# 0                     5084                  204624  53628       340296
# 1                      632                   87656  17924         4520
# 2                      920                   15244   6948         4756
# 3                     2108                   54416  19192        72096
# 4                     1232                   61376  17872       113688
#
#    República Dominicana  Rumanía   Total_x  Ucrania  Venezuela  \
# 0                 34140   254560  29005708    65968      95976
# 1                 21072   166692   4594760     9272      23120
# 2                 18116    22772   3602696     3412      25792
# 3                 20548    41612   4066804     8608      23944
# 4                 18760    29468   7675432     6412     271688
#
#    Educación primaria e inferior  Educación superior  \
# 0                        5329040             7889300
# 1                         677896             1516724
# 2                         556792             1210520
# 3                         551496             1146044
# 4                        1403748             2200628
#
#    Primera etapa de educación secundaria y similar  \
# 0                                         10066364
# 1                                          1391740
# 2                                          1035988
# 3                                          1295332
# 4                                          2267688
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                            5721004
# 1                                            1008400
# 2                                             799396
# 3                                            1073932
# 4                                            1803368
#
#     Total_y   Hombres   Mujeres     Total
# 0  29005708  14191520  14814188  29005708
# 1   4594760   2257748   2337012   4594760
# 2   3602696   1703944   1898752   3602696
# 3   4066804   2017116   2049688   4066804
# 4   7675432   3773072   3902360   7675432

# %% [markdown]
# "Total_x" y "Total_y" son duplciados de la columna "Total" así que los eliminamos

# %%
df_concatenado = df_concatenado.drop(columns=["Total_x", "Total_y"])
df_concatenado.head()
# Out:
#    Código comunidad         Nombre comunidad  Argentina  Bolivia  China  \
# 0                 1                Andalucía     179896    68788  70360
# 1                 2                   Aragón      16420     4852  19048
# 2                 3  Asturias, Principado de      17804     2264   4812
# 3                 4           Balears, Illes     109768    27656  19624
# 4                 5                 Canarias      71592    15352  34976
#
#    Colombia    Cuba  Ecuador    España  Francia  Marruecos  \
# 0    168684   44220    95272  25504212   109364     694492
# 1     56884   14292    50548   3830992    15676      86312
# 2     27380   18996    18680   3280668     9356      14500
# 3     92660   27096    62752   2939664    33368     107764
# 4    136776  181500    26268   5980416    27628     100384
#
#    Otros países de América  Otros países de Asia  Otros países de Europa  \
# 0                   309596                 97952                  608596
# 1                    89092                 18628                   61128
# 2                    51244                  5660                   53372
# 3                   114968                 43276                  245684
# 4                    98672                 51412                  429960
#
#    Otros países de Oceanía  Otros países de África   Perú  Reino Unido  \
# 0                     5084                  204624  53628       340296
# 1                      632                   87656  17924         4520
# 2                      920                   15244   6948         4756
# 3                     2108                   54416  19192        72096
# 4                     1232                   61376  17872       113688
#
#    República Dominicana  Rumanía  Ucrania  Venezuela  \
# 0                 34140   254560    65968      95976
# 1                 21072   166692     9272      23120
# 2                 18116    22772     3412      25792
# 3                 20548    41612     8608      23944
# 4                 18760    29468     6412     271688
#
#    Educación primaria e inferior  Educación superior  \
# 0                        5329040             7889300
# 1                         677896             1516724
# 2                         556792             1210520
# 3                         551496             1146044
# 4                        1403748             2200628
#
#    Primera etapa de educación secundaria y similar  \
# 0                                         10066364
# 1                                          1391740
# 2                                          1035988
# 3                                          1295332
# 4                                          2267688
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                            5721004
# 1                                            1008400
# 2                                             799396
# 3                                            1073932
# 4                                            1803368
#
#     Hombres   Mujeres     Total
# 0  14191520  14814188  29005708
# 1   2257748   2337012   4594760
# 2   1703944   1898752   3602696
# 3   2017116   2049688   4066804
# 4   3773072   3902360   7675432

# %%
#Renombramos el dataframe para mayor claridad
df_nivel_educativo_comunidades=df_concatenado
df_nivel_educativo_comunidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 29 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Código comunidad                                                              19 non-null     int64
#  1   Nombre comunidad                                                              19 non-null     object
#  2   Argentina                                                                     19 non-null     int64
#  3   Bolivia                                                                       19 non-null     int64
#  4   China                                                                         19 non-null     int64
#  5   Colombia                                                                      19 non-null     int64
#  6   Cuba                                                                          19 non-null     int64
#  7   Ecuador                                                                       19 non-null     int64
#  8   España                                                                        19 non-null     int64
#  9   Francia                                                                       19 non-null     int64
#  10  Marruecos                                                                     19 non-null     int64
#  11  Otros países de América                                                       19 non-null     int64
#  12  Otros países de Asia                                                          19 non-null     int64
#  13  Otros países de Europa                                                        19 non-null     int64
#  14  Otros países de Oceanía                                                       19 non-null     int64
#  15  Otros países de África                                                        19 non-null     int64
#  16  Perú                                                                          19 non-null     int64
#  17  Reino Unido                                                                   19 non-null     int64
#  18  República Dominicana                                                          19 non-null     int64
#  19  Rumanía                                                                       19 non-null     int64
#  20  Ucrania                                                                       19 non-null     int64
#  21  Venezuela                                                                     19 non-null     int64
#  22  Educación primaria e inferior                                                 19 non-null     int64
#  23  Educación superior                                                            19 non-null     int64
#  24  Primera etapa de educación secundaria y similar                               19 non-null     int64
#  25  Segunda etapa de educación secundaria y educación postsecundaria no superior  19 non-null     int64
#  26  Hombres                                                                       19 non-null     int64
#  27  Mujeres                                                                       19 non-null     int64
#  28  Total                                                                         19 non-null     int64
# dtypes: int64(28), object(1)
# memory usage: 4.4+ KB

# %%
df_nivel_educativo_comunidades["Nombre comunidad"].unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias, Principado de', 'Balears, Illes',
#        'Canarias', 'Cantabria', 'Castilla y León', 'Castilla - La Mancha',
#        'Cataluña', 'Comunitat Valenciana', 'Extremadura', 'Galicia',
#        'Madrid, Comunidad de', 'Murcia, Región de',
#        'Navarra, Comunidad Foral de', 'País Vasco', 'Rioja, La', 'Ceuta',
#        'Melilla'], dtype=object)

# %%
# Reordenar las columnas para que 'Hombres' y 'Mujeres' aparezcan después de 'Nombre comunidad'
columnas_reordenadas = (
    ['Código comunidad', 'Nombre comunidad', 'Hombres', 'Mujeres'] +
    [col for col in df_nivel_educativo_comunidades.columns if col not in ['Código comunidad', 'Nombre comunidad', 'Hombres', 'Mujeres']]
)

df_nivel_educativo_comunidades = df_nivel_educativo_comunidades[columnas_reordenadas]

# Mostrar las primeras filas del DataFrame reordenado
df_nivel_educativo_comunidades.head()
# Out:
#    Código comunidad         Nombre comunidad   Hombres   Mujeres  Argentina  \
# 0                 1                Andalucía  14191520  14814188     179896
# 1                 2                   Aragón   2257748   2337012      16420
# 2                 3  Asturias, Principado de   1703944   1898752      17804
# 3                 4           Balears, Illes   2017116   2049688     109768
# 4                 5                 Canarias   3773072   3902360      71592
#
#    Bolivia  China  Colombia    Cuba  Ecuador    España  Francia  Marruecos  \
# 0    68788  70360    168684   44220    95272  25504212   109364     694492
# 1     4852  19048     56884   14292    50548   3830992    15676      86312
# 2     2264   4812     27380   18996    18680   3280668     9356      14500
# 3    27656  19624     92660   27096    62752   2939664    33368     107764
# 4    15352  34976    136776  181500    26268   5980416    27628     100384
#
#    Otros países de América  Otros países de Asia  Otros países de Europa  \
# 0                   309596                 97952                  608596
# 1                    89092                 18628                   61128
# 2                    51244                  5660                   53372
# 3                   114968                 43276                  245684
# 4                    98672                 51412                  429960
#
#    Otros países de Oceanía  Otros países de África   Perú  Reino Unido  \
# 0                     5084                  204624  53628       340296
# 1                      632                   87656  17924         4520
# 2                      920                   15244   6948         4756
# 3                     2108                   54416  19192        72096
# 4                     1232                   61376  17872       113688
#
#    República Dominicana  Rumanía  Ucrania  Venezuela  \
# 0                 34140   254560    65968      95976
# 1                 21072   166692     9272      23120
# 2                 18116    22772     3412      25792
# 3                 20548    41612     8608      23944
# 4                 18760    29468     6412     271688
#
#    Educación primaria e inferior  Educación superior  \
# 0                        5329040             7889300
# 1                         677896             1516724
# 2                         556792             1210520
# 3                         551496             1146044
# 4                        1403748             2200628
#
#    Primera etapa de educación secundaria y similar  \
# 0                                         10066364
# 1                                          1391740
# 2                                          1035988
# 3                                          1295332
# 4                                          2267688
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                            5721004
# 1                                            1008400
# 2                                             799396
# 3                                            1073932
# 4                                            1803368
#
#       Total
# 0  29005708
# 1   4594760
# 2   3602696
# 3   4066804
# 4   7675432

# %% [markdown]
# Vamos a generar categorías que serán encabezados del DataFrame

# %%
# Crear una lista de categorías para las columnas del DataFrame
categorias = (
    ['Comunidades y ciudades autónomas'] * 2 +  # Código comunidad, Nombre comunidad
    ['Sexo'] * 2 +  # Hombres, Mujeres
    ['País de nacimiento'] * 20 +  # Países de nacimiento
    ['Nivel educativo'] * 4 +  # Niveles educativos
    ['Población mayor de 15 años']  # Total
)

# Asignar las categorías a las columnas del DataFrame
df_nivel_educativo_comunidades.columns = pd.MultiIndex.from_tuples(zip(categorias, df_nivel_educativo_comunidades.columns))
df_nivel_educativo_comunidades.head()
# Out:
#   Comunidades y ciudades autónomas                               Sexo  \
#                   Código comunidad         Nombre comunidad   Hombres
# 0                                1                Andalucía  14191520
# 1                                2                   Aragón   2257748
# 2                                3  Asturias, Principado de   1703944
# 3                                4           Balears, Illes   2017116
# 4                                5                 Canarias   3773072
#
#             País de nacimiento                                          \
#     Mujeres          Argentina Bolivia  China Colombia    Cuba Ecuador
# 0  14814188             179896   68788  70360   168684   44220   95272
# 1   2337012              16420    4852  19048    56884   14292   50548
# 2   1898752              17804    2264   4812    27380   18996   18680
# 3   2049688             109768   27656  19624    92660   27096   62752
# 4   3902360              71592   15352  34976   136776  181500   26268
#
#                                                                             \
#      España Francia Marruecos Otros países de América Otros países de Asia
# 0  25504212  109364    694492                  309596                97952
# 1   3830992   15676     86312                   89092                18628
# 2   3280668    9356     14500                   51244                 5660
# 3   2939664   33368    107764                  114968                43276
# 4   5980416   27628    100384                   98672                51412
#
#                                                                          \
#   Otros países de Europa Otros países de Oceanía Otros países de África
# 0                 608596                    5084                 204624
# 1                  61128                     632                  87656
# 2                  53372                     920                  15244
# 3                 245684                    2108                  54416
# 4                 429960                    1232                  61376
#
#                                                                      \
#     Perú Reino Unido República Dominicana Rumanía Ucrania Venezuela
# 0  53628      340296                34140  254560   65968     95976
# 1  17924        4520                21072  166692    9272     23120
# 2   6948        4756                18116   22772    3412     25792
# 3  19192       72096                20548   41612    8608     23944
# 4  17872      113688                18760   29468    6412    271688
#
#                 Nivel educativo                     \
#   Educación primaria e inferior Educación superior
# 0                       5329040            7889300
# 1                        677896            1516724
# 2                        556792            1210520
# 3                        551496            1146044
# 4                       1403748            2200628
#
#                                                    \
#   Primera etapa de educación secundaria y similar
# 0                                        10066364
# 1                                         1391740
# 2                                         1035988
# 3                                         1295332
# 4                                         2267688
#
#                                                                                 \
#   Segunda etapa de educación secundaria y educación postsecundaria no superior
# 0                                            5721004
# 1                                            1008400
# 2                                             799396
# 3                                            1073932
# 4                                            1803368
#
#   Población mayor de 15 años
#                        Total
# 0                   29005708
# 1                    4594760
# 2                    3602696
# 3                    4066804
# 4                    7675432

# %%
df_nivel_educativo_comunidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 29 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   (Comunidades y ciudades autónomas, Código comunidad)                                             19 non-null     int64
#  1   (Comunidades y ciudades autónomas, Nombre comunidad)                                             19 non-null     object
#  2   (Sexo, Hombres)                                                                                  19 non-null     int64
#  3   (Sexo, Mujeres)                                                                                  19 non-null     int64
#  4   (País de nacimiento, Argentina)                                                                  19 non-null     int64
#  5   (País de nacimiento, Bolivia)                                                                    19 non-null     int64
#  6   (País de nacimiento, China)                                                                      19 non-null     int64
#  7   (País de nacimiento, Colombia)                                                                   19 non-null     int64
#  8   (País de nacimiento, Cuba)                                                                       19 non-null     int64
#  9   (País de nacimiento, Ecuador)                                                                    19 non-null     int64
#  10  (País de nacimiento, España)                                                                     19 non-null     int64
#  11  (País de nacimiento, Francia)                                                                    19 non-null     int64
#  12  (País de nacimiento, Marruecos)                                                                  19 non-null     int64
#  13  (País de nacimiento, Otros países de América)                                                    19 non-null     int64
#  14  (País de nacimiento, Otros países de Asia)                                                       19 non-null     int64
#  15  (País de nacimiento, Otros países de Europa)                                                     19 non-null     int64
#  16  (País de nacimiento, Otros países de Oceanía)                                                    19 non-null     int64
#  17  (País de nacimiento, Otros países de África)                                                     19 non-null     int64
#  18  (País de nacimiento, Perú)                                                                       19 non-null     int64
#  19  (País de nacimiento, Reino Unido)                                                                19 non-null     int64
#  20  (País de nacimiento, República Dominicana)                                                       19 non-null     int64
#  21  (País de nacimiento, Rumanía)                                                                    19 non-null     int64
#  22  (País de nacimiento, Ucrania)                                                                    19 non-null     int64
#  23  (País de nacimiento, Venezuela)                                                                  19 non-null     int64
#  24  (Nivel educativo, Educación primaria e inferior)                                                 19 non-null     int64
#  25  (Nivel educativo, Educación superior)                                                            19 non-null     int64
#  26  (Nivel educativo, Primera etapa de educación secundaria y similar)                               19 non-null     int64
#  27  (Nivel educativo, Segunda etapa de educación secundaria y educación postsecundaria no superior)  19 non-null     int64
#  28  (Población mayor de 15 años, Total)                                                              19 non-null     int64
# dtypes: int64(28), object(1)
# memory usage: 4.4+ KB

# %%
# Guardamos el DataFrame en un archivo CSV
df_nivel_educativo_comunidades.to_csv("datos_limpiados/comunidades/nivel_educativo_comunidades_limpio.csv", index=False)

# %% [markdown]
# ## Limpiamos el dataframe con la información del nivel educativo a nivel nacional

# %%
df_nivel_educativo_nacional = pd.read_csv("datos/ine/nivel_educativo_nacional.csv", encoding= 'latin-1', sep=';')

# %%
df_nivel_educativo_nacional.head()
# Out:
#    Total Nacional  Comunidades y Ciudades Autónomas  Provincias  \
# 0  Total Nacional                               NaN         NaN
# 1  Total Nacional                               NaN         NaN
# 2  Total Nacional                               NaN         NaN
# 3  Total Nacional                               NaN         NaN
# 4  Total Nacional                               NaN         NaN
#
#   País de nacimiento   Nivel de formación alcanzado     Sexo  Periodo  \
# 0              Total                          Total    Total     2022
# 1              Total                          Total  Hombres     2022
# 2              Total                          Total  Mujeres     2022
# 3              Total  Educación primaria e inferior    Total     2022
# 4              Total  Educación primaria e inferior  Hombres     2022
#
#         Total
# 0  40.899.207
# 1  19.897.392
# 2  21.001.815
# 3   6.545.911
# 4   2.747.314

# %%
df_nivel_educativo_nacional.sample(20)
# Out:
#      Total Nacional  Comunidades y Ciudades Autónomas  Provincias  \
# 159  Total Nacional                               NaN         NaN
# 12   Total Nacional                               NaN         NaN
# 271  Total Nacional                               NaN         NaN
# 207  Total Nacional                               NaN         NaN
# 231  Total Nacional                               NaN         NaN
# 177  Total Nacional                               NaN         NaN
# 80   Total Nacional                               NaN         NaN
# 21   Total Nacional                               NaN         NaN
# 151  Total Nacional                               NaN         NaN
# 270  Total Nacional                               NaN         NaN
# 61   Total Nacional                               NaN         NaN
# 107  Total Nacional                               NaN         NaN
# 215  Total Nacional                               NaN         NaN
# 11   Total Nacional                               NaN         NaN
# 176  Total Nacional                               NaN         NaN
# 26   Total Nacional                               NaN         NaN
# 278  Total Nacional                               NaN         NaN
# 202  Total Nacional                               NaN         NaN
# 204  Total Nacional                               NaN         NaN
# 252  Total Nacional                               NaN         NaN
#
#        País de nacimiento                       Nivel de formación alcanzado  \
# 159  República Dominicana  Segunda etapa de educación secundaria y educac...
# 12                  Total                                 Educación superior
# 271                 China                                              Total
# 207              Colombia                                 Educación superior
# 231                  Perú    Primera etapa de educación secundaria y similar
# 177             Argentina                                 Educación superior
# 80                Ucrania                      Educación primaria e inferior
# 21                 España    Primera etapa de educación secundaria y similar
# 151  República Dominicana                                              Total
# 270                 China                                              Total
# 61                Rumanía                                              Total
# 107             Marruecos                                              Total
# 215               Ecuador                      Educación primaria e inferior
# 11                  Total  Segunda etapa de educación secundaria y educac...
# 176             Argentina  Segunda etapa de educación secundaria y educac...
# 26                 España  Segunda etapa de educación secundaria y educac...
# 278                 China    Primera etapa de educación secundaria y similar
# 202              Colombia    Primera etapa de educación secundaria y similar
# 204              Colombia  Segunda etapa de educación secundaria y educac...
# 252             Venezuela                                 Educación superior
#
#         Sexo  Periodo       Total
# 159    Total     2022      56.357
# 12     Total     2022  13.149.124
# 271  Hombres     2022      83.772
# 207    Total     2022     138.227
# 231    Total     2022      48.049
# 177    Total     2022     131.600
# 80   Mujeres     2022      14.320
# 21     Total     2022  10.639.121
# 151  Hombres     2022      71.998
# 270    Total     2022     180.511
# 61   Hombres     2022     252.395
# 107  Mujeres     2022     380.562
# 215  Mujeres     2022      33.750
# 11   Mujeres     2022   4.332.353
# 176  Mujeres     2022      47.963
# 26   Mujeres     2022   3.360.203
# 278  Mujeres     2022      30.893
# 202  Hombres     2022      52.462
# 204    Total     2022     188.809
# 252    Total     2022     201.670

# %% [markdown]
# En primer lugar eliminamos las columnas "Comunidades y Ciudades Autónomas" y "Provincias" que están vacías

# %%
# Eliminamos las columnas 'Provincias' y 'Comunidades y Ciudades Autónomas'
df_nivel_educativo_nacional.drop(columns=['Comunidades y Ciudades Autónomas', 'Provincias'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_nivel_educativo_nacional.head()
# Out:
#    Total Nacional País de nacimiento   Nivel de formación alcanzado     Sexo  \
# 0  Total Nacional              Total                          Total    Total
# 1  Total Nacional              Total                          Total  Hombres
# 2  Total Nacional              Total                          Total  Mujeres
# 3  Total Nacional              Total  Educación primaria e inferior    Total
# 4  Total Nacional              Total  Educación primaria e inferior  Hombres
#
#    Periodo       Total
# 0     2022  40.899.207
# 1     2022  19.897.392
# 2     2022  21.001.815
# 3     2022   6.545.911
# 4     2022   2.747.314

# %% [markdown]
# Formateamos la columna 'Total'

# %%
# Convertimos la columna "Total" a int64
df_nivel_educativo_nacional['Total'] = df_nivel_educativo_nacional['Total'].str.replace('.', '').astype('int64')
df_nivel_educativo_nacional.head()
# Out:
#    Total Nacional País de nacimiento   Nivel de formación alcanzado     Sexo  \
# 0  Total Nacional              Total                          Total    Total
# 1  Total Nacional              Total                          Total  Hombres
# 2  Total Nacional              Total                          Total  Mujeres
# 3  Total Nacional              Total  Educación primaria e inferior    Total
# 4  Total Nacional              Total  Educación primaria e inferior  Hombres
#
#    Periodo     Total
# 0     2022  40899207
# 1     2022  19897392
# 2     2022  21001815
# 3     2022   6545911
# 4     2022   2747314

# %% [markdown]
# Renombraos la columna "Total Nacional" a País, y asignamos a sus filas el valor España. De esta manea a parte de hacer más legible la columna favorecemos una posible ampliación de datos para incorporar los de otros países.

# %%
# Renombrar la columna "Total Nacional" a "País"
df_nivel_educativo_nacional.rename(columns={"Total Nacional": "Nombre del país"}, inplace=True)

# Asignar el valor "España" a todas las filas en la columna "País"
df_nivel_educativo_nacional["Nombre del país"] = "España"

# Mostrar las primeras filas para verificar los cambios
df_nivel_educativo_nacional.head()
# Out:
#   Nombre del país País de nacimiento   Nivel de formación alcanzado     Sexo  \
# 0          España              Total                          Total    Total
# 1          España              Total                          Total  Hombres
# 2          España              Total                          Total  Mujeres
# 3          España              Total  Educación primaria e inferior    Total
# 4          España              Total  Educación primaria e inferior  Hombres
#
#    Periodo     Total
# 0     2022  40899207
# 1     2022  19897392
# 2     2022  21001815
# 3     2022   6545911
# 4     2022   2747314

# %% [markdown]
# Pivotamos las columnas "País de nacimiento", "Nivel de formación alcanzado" y "Sexo" para tener toda la información a nivel nacional en una sola fila. Dejamos fuera la columna Periodo, pues es siempre el 2022 y por tanto no aporta información relevante.

# %%
# Pivotamos la columna "País de nacimiento" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_pais = df_nivel_educativo_nacional.pivot_table(
    index=['Nombre del país'],
    columns='País de nacimiento',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_pais.head()
# Out:
# País de nacimiento Nombre del país  Argentina  Bolivia   China  Colombia  \
# 0                           España    1245180   701868  722044   2123816
#
# País de nacimiento    Cuba  Ecuador     España  Francia  Marruecos  \
# 0                   678776  1642368  135390128   808136    3601748
#
# País de nacimiento  Otros países de América  Otros países de Asia  \
# 0                                   3052212               1182364
#
# País de nacimiento  Otros países de Europa  Otros países de Oceanía  \
# 0                                  3975804                    31868
#
# País de nacimiento  Otros países de África    Perú  Reino Unido  \
# 0                                  1445768  997400      1124284
#
# País de nacimiento  República Dominicana  Rumanía      Total  Ucrania  \
# 0                                 719432  2123684  163596828   424240
#
# País de nacimiento  Venezuela
# 0                     1605708

# %%
# Pivotamos la columna "Nivel de formación alcanzado" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_nivel = df_nivel_educativo_nacional.pivot_table(
    index=['Nombre del país'],
    columns='Nivel de formación alcanzado',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_nivel.head()
# Out:
# Nivel de formación alcanzado Nombre del país  Educación primaria e inferior  \
# 0                                     España                       26183644
#
# Nivel de formación alcanzado  Educación superior  \
# 0                                       52596496
#
# Nivel de formación alcanzado  Primera etapa de educación secundaria y similar  \
# 0                                                                    49384308
#
# Nivel de formación alcanzado  Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                                                      35432380
#
# Nivel de formación alcanzado      Total
# 0                             163596828

# %%
# Pivotamos la columna "Sexo" para que sus valores únicos sean columnas
df_nivel_educativo_pivotado_sexo = df_nivel_educativo_nacional.pivot_table(
    index=['Nombre del país'],
    columns='Sexo',
    values='Total',
    aggfunc='sum'
).reset_index()

# Mostramos las primeras filas del DataFrame pivotado
df_nivel_educativo_pivotado_sexo.head()
# Out:
# Sexo Nombre del país   Hombres   Mujeres      Total
# 0             España  79589568  84007260  163596828

# %%
 # Concatenamos los tres DataFrames generados con outer join
df_concatenado = pd.merge(
    pd.merge(
        df_nivel_educativo_pivotado_pais, 
        df_nivel_educativo_pivotado_nivel, 
        on=['Nombre del país'], 
        how='outer'
    ), 
    df_nivel_educativo_pivotado_sexo, 
    on=['Nombre del país'], 
    how='outer'
)

# Mostramos las primeras filas del DataFrame concatenado
df_concatenado.head()
# Out:
#   Nombre del país  Argentina  Bolivia   China  Colombia    Cuba  Ecuador  \
# 0          España    1245180   701868  722044   2123816  678776  1642368
#
#       España  Francia  Marruecos  Otros países de América  \
# 0  135390128   808136    3601748                  3052212
#
#    Otros países de Asia  Otros países de Europa  Otros países de Oceanía  \
# 0               1182364                 3975804                    31868
#
#    Otros países de África    Perú  Reino Unido  República Dominicana  Rumanía  \
# 0                 1445768  997400      1124284                719432  2123684
#
#      Total_x  Ucrania  Venezuela  Educación primaria e inferior  \
# 0  163596828   424240    1605708                       26183644
#
#    Educación superior  Primera etapa de educación secundaria y similar  \
# 0            52596496                                         49384308
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                           35432380
#
#      Total_y   Hombres   Mujeres      Total
# 0  163596828  79589568  84007260  163596828

# %% [markdown]
# Eliminamos las columnas "Total_X" y "Total_y" del Dataframe pues son duplicados de la columa "Total"

# %%
# Eliminar las columnas Total_x y Total_y del DataFrame
df_concatenado = df_concatenado.drop(columns=['Total_x', 'Total_y'])

df_concatenado.head()
# Out:
#   Nombre del país  Argentina  Bolivia   China  Colombia    Cuba  Ecuador  \
# 0          España    1245180   701868  722044   2123816  678776  1642368
#
#       España  Francia  Marruecos  Otros países de América  \
# 0  135390128   808136    3601748                  3052212
#
#    Otros países de Asia  Otros países de Europa  Otros países de Oceanía  \
# 0               1182364                 3975804                    31868
#
#    Otros países de África    Perú  Reino Unido  República Dominicana  Rumanía  \
# 0                 1445768  997400      1124284                719432  2123684
#
#    Ucrania  Venezuela  Educación primaria e inferior  Educación superior  \
# 0   424240    1605708                       26183644            52596496
#
#    Primera etapa de educación secundaria y similar  \
# 0                                         49384308
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                           35432380
#
#     Hombres   Mujeres      Total
# 0  79589568  84007260  163596828

# %%
#Renombramos el dataframe para mayor claridad
df_nivel_educativo_nacional=df_concatenado
df_nivel_educativo_nacional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 28 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Nombre del país                                                               1 non-null      object
#  1   Argentina                                                                     1 non-null      int64
#  2   Bolivia                                                                       1 non-null      int64
#  3   China                                                                         1 non-null      int64
#  4   Colombia                                                                      1 non-null      int64
#  5   Cuba                                                                          1 non-null      int64
#  6   Ecuador                                                                       1 non-null      int64
#  7   España                                                                        1 non-null      int64
#  8   Francia                                                                       1 non-null      int64
#  9   Marruecos                                                                     1 non-null      int64
#  10  Otros países de América                                                       1 non-null      int64
#  11  Otros países de Asia                                                          1 non-null      int64
#  12  Otros países de Europa                                                        1 non-null      int64
#  13  Otros países de Oceanía                                                       1 non-null      int64
#  14  Otros países de África                                                        1 non-null      int64
#  15  Perú                                                                          1 non-null      int64
#  16  Reino Unido                                                                   1 non-null      int64
#  17  República Dominicana                                                          1 non-null      int64
#  18  Rumanía                                                                       1 non-null      int64
#  19  Ucrania                                                                       1 non-null      int64
#  20  Venezuela                                                                     1 non-null      int64
#  21  Educación primaria e inferior                                                 1 non-null      int64
#  22  Educación superior                                                            1 non-null      int64
#  23  Primera etapa de educación secundaria y similar                               1 non-null      int64
#  24  Segunda etapa de educación secundaria y educación postsecundaria no superior  1 non-null      int64
#  25  Hombres                                                                       1 non-null      int64
#  26  Mujeres                                                                       1 non-null      int64
#  27  Total                                                                         1 non-null      int64
# dtypes: int64(27), object(1)
# memory usage: 356.0+ bytes

# %% [markdown]
# Generamos una columna de código de país. En el presente análisis solo se incluyen datos de España, pero es util incluir esta columna de cara a una posible inclusión futura de otros páises

# %%
df_nivel_educativo_nacional["Código país"] = range(1, len(df_nivel_educativo_nacional) + 1)

# Mostrar las primeras filas para verificar los cambios
df_nivel_educativo_nacional.head()
# Out:
#   Nombre del país  Argentina  Bolivia   China  Colombia    Cuba  Ecuador  \
# 0          España    1245180   701868  722044   2123816  678776  1642368
#
#       España  Francia  Marruecos  Otros países de América  \
# 0  135390128   808136    3601748                  3052212
#
#    Otros países de Asia  Otros países de Europa  Otros países de Oceanía  \
# 0               1182364                 3975804                    31868
#
#    Otros países de África    Perú  Reino Unido  República Dominicana  Rumanía  \
# 0                 1445768  997400      1124284                719432  2123684
#
#    Ucrania  Venezuela  Educación primaria e inferior  Educación superior  \
# 0   424240    1605708                       26183644            52596496
#
#    Primera etapa de educación secundaria y similar  \
# 0                                         49384308
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                           35432380
#
#     Hombres   Mujeres      Total  Código país
# 0  79589568  84007260  163596828            1

# %% [markdown]
# Vamosa reordenar las columnas para que "Codigo país" sea la primera columna y "Hombres" y "Mujeres vayan después de "Nombre del País"

# %%
# Reordenar las columnas
columnas_reordenadas = (
    ['Código país', 'Nombre del país', 'Hombres', 'Mujeres'] +
    [col for col in df_nivel_educativo_nacional.columns if col not in ['Código país', 'Nombre del país', 'Hombres', 'Mujeres']]
)

df_nivel_educativo_nacional = df_nivel_educativo_nacional[columnas_reordenadas]

# Mostrar las primeras filas del DataFrame reordenado
df_nivel_educativo_nacional.head()
# Out:
#    Código país Nombre del país   Hombres   Mujeres  Argentina  Bolivia  \
# 0            1          España  79589568  84007260    1245180   701868
#
#     China  Colombia    Cuba  Ecuador     España  Francia  Marruecos  \
# 0  722044   2123816  678776  1642368  135390128   808136    3601748
#
#    Otros países de América  Otros países de Asia  Otros países de Europa  \
# 0                  3052212               1182364                 3975804
#
#    Otros países de Oceanía  Otros países de África    Perú  Reino Unido  \
# 0                    31868                 1445768  997400      1124284
#
#    República Dominicana  Rumanía  Ucrania  Venezuela  \
# 0                719432  2123684   424240    1605708
#
#    Educación primaria e inferior  Educación superior  \
# 0                       26183644            52596496
#
#    Primera etapa de educación secundaria y similar  \
# 0                                         49384308
#
#    Segunda etapa de educación secundaria y educación postsecundaria no superior  \
# 0                                           35432380
#
#        Total
# 0  163596828

# %% [markdown]
# Generamos encabezados para el DataFrame

# %%
# Crear una lista de categorías para las columnas del DataFrame
categorias = (
    ['Países'] * 2 +  # Código país, Nombre país
    ['Sexo'] * 2 +  # Hombres, Mujeres
    ['País de nacimiento'] * 20 +  # Países de nacimiento
    ['Nivel educativo'] * 4 +  # Niveles educativos
    ['Población mayor de 15 años']  # Total
)

# Asignar las categorías a las columnas del DataFrame
df_nivel_educativo_nacional.columns = pd.MultiIndex.from_tuples(zip(categorias, df_nivel_educativo_nacional.columns))
df_nivel_educativo_nacional.head()
# Out:
#        Países                      Sexo           País de nacimiento          \
#   Código país Nombre del país   Hombres   Mujeres          Argentina Bolivia
# 0           1          España  79589568  84007260            1245180  701868
#
#                                                                   \
#     China Colombia    Cuba  Ecuador     España Francia Marruecos
# 0  722044  2123816  678776  1642368  135390128  808136   3601748
#
#                                                                        \
#   Otros países de América Otros países de Asia Otros países de Europa
# 0                 3052212              1182364                3975804
#
#                                                                       \
#   Otros países de Oceanía Otros países de África    Perú Reino Unido
# 0                   31868                1445768  997400     1124284
#
#                                                    \
#   República Dominicana  Rumanía Ucrania Venezuela
# 0               719432  2123684  424240   1605708
#
#                 Nivel educativo                     \
#   Educación primaria e inferior Educación superior
# 0                      26183644           52596496
#
#                                                    \
#   Primera etapa de educación secundaria y similar
# 0                                        49384308
#
#                                                                                 \
#   Segunda etapa de educación secundaria y educación postsecundaria no superior
# 0                                           35432380
#
#   Población mayor de 15 años
#                        Total
# 0                  163596828

# %%
# Guardamos el DataFrame en un archivo CSV
df_nivel_educativo_nacional.to_csv("datos_limpiados/nacionales/nivel_educativo_nacional_limpio.csv", index=False)
