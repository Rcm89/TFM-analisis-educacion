# %%
# Para trabajar con regex
# -----------------------------------------------------------------------
import re

# Para trabajar con ficheros
# -----------------------------------------------------------------------
import os


# Para trabajar con los DataFrames
# -----------------------------------------------------------------------
import pandas as pd

# Para poner barras progreso
# -----------------------------------------------------------------------
from tqdm import tqdm



# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Ignorar warings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# Librerias para generar gráficas
# ----------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Cargamos los archivos del INE

# %%
df_censo_2022 = pd.read_csv("datos/ine/censo_2022.csv", encoding= 'latin-1', sep=';')

# %%
df_censo_2022.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias Nacionalidad  \
# 0  Total Nacional                              NaN         NaN        Total
# 1  Total Nacional                     01 Andalucía         NaN        Total
# 2  Total Nacional                     01 Andalucía   29 Málaga        Total
# 3  Total Nacional                     01 Andalucía     23 Jaén        Total
# 4  Total Nacional                     01 Andalucía  04 Almería        Total
#
#     Sexo              Edad  Periodo       Total
# 0  Total  Todas las edades     2022  47.486.727
# 1  Total  Todas las edades     2022   8.511.167
# 2  Total  Todas las edades     2022   1.715.109
# 3  Total  Todas las edades     2022     624.191
# 4  Total  Todas las edades     2022     739.541

# %%
df_censo_2022.sample(35)
# Out:
#     Total Nacional Comunidades y Ciudades Autónomas  \
# 23  Total Nacional          08 Castilla - La Mancha
# 25  Total Nacional          08 Castilla - La Mancha
# 49  Total Nacional                   11 Extremadura
# 51  Total Nacional                       12 Galicia
# 67  Total Nacional                     17 Rioja, La
# 58  Total Nacional             14 Murcia, Región de
# 9   Total Nacional                     01 Andalucía
# 31  Total Nacional               07 Castilla y León
# 7   Total Nacional                     01 Andalucía
# 17  Total Nacional                04 Balears, Illes
# 55  Total Nacional                       12 Galicia
# 6   Total Nacional                     01 Andalucía
# 39  Total Nacional                      09 Cataluña
# 2   Total Nacional                     01 Andalucía
# 20  Total Nacional                      05 Canarias
# 69  Total Nacional                         18 Ceuta
# 13  Total Nacional                        02 Aragón
# 48  Total Nacional                   11 Extremadura
# 64  Total Nacional                    16 País Vasco
# 71  Total Nacional                       19 Melilla
# 28  Total Nacional          08 Castilla - La Mancha
# 54  Total Nacional                       12 Galicia
# 30  Total Nacional               07 Castilla y León
# 50  Total Nacional                   11 Extremadura
# 27  Total Nacional          08 Castilla - La Mancha
# 19  Total Nacional                      05 Canarias
# 43  Total Nacional                      09 Cataluña
# 22  Total Nacional                     06 Cantabria
# 66  Total Nacional                     17 Rioja, La
# 35  Total Nacional               07 Castilla y León
# 44  Total Nacional          10 Comunitat Valenciana
# 15  Total Nacional       03 Asturias, Principado de
# 1   Total Nacional                     01 Andalucía
# 60  Total Nacional   15 Navarra, Comunidad Foral de
# 14  Total Nacional       03 Asturias, Principado de
#
#                    Provincias Nacionalidad   Sexo              Edad  Periodo  \
# 23                        NaN        Total  Total  Todas las edades     2022
# 25             13 Ciudad Real        Total  Total  Todas las edades     2022
# 49                 10 Cáceres        Total  Total  Todas las edades     2022
# 51                        NaN        Total  Total  Todas las edades     2022
# 67               26 Rioja, La        Total  Total  Todas las edades     2022
# 58                        NaN        Total  Total  Todas las edades     2022
# 9                  14 Córdoba        Total  Total  Todas las edades     2022
# 31                   42 Soria        Total  Total  Todas las edades     2022
# 7                  41 Sevilla        Total  Total  Todas las edades     2022
# 17          07 Balears, Illes        Total  Total  Todas las edades     2022
# 55                 32 Ourense        Total  Total  Todas las edades     2022
# 6                    11 Cádiz        Total  Total  Todas las edades     2022
# 39                        NaN        Total  Total  Todas las edades     2022
# 2                   29 Málaga        Total  Total  Todas las edades     2022
# 20             35 Palmas, Las        Total  Total  Todas las edades     2022
# 69                   51 Ceuta        Total  Total  Todas las edades     2022
# 13                  22 Huesca        Total  Total  Todas las edades     2022
# 48                        NaN        Total  Total  Todas las edades     2022
# 64             01 Araba/Álava        Total  Total  Todas las edades     2022
# 71                 52 Melilla        Total  Total  Todas las edades     2022
# 28                  16 Cuenca        Total  Total  Todas las edades     2022
# 54                    27 Lugo        Total  Total  Todas las edades     2022
# 30                  09 Burgos        Total  Total  Todas las edades     2022
# 50                 06 Badajoz        Total  Total  Todas las edades     2022
# 27                  45 Toledo        Total  Total  Todas las edades     2022
# 19  38 Santa Cruz de Tenerife        Total  Total  Todas las edades     2022
# 43               43 Tarragona        Total  Total  Todas las edades     2022
# 22               39 Cantabria        Total  Total  Todas las edades     2022
# 66                        NaN        Total  Total  Todas las edades     2022
# 35                  49 Zamora        Total  Total  Todas las edades     2022
# 44                        NaN        Total  Total  Todas las edades     2022
# 15                33 Asturias        Total  Total  Todas las edades     2022
# 1                         NaN        Total  Total  Todas las edades     2022
# 60                        NaN        Total  Total  Todas las edades     2022
# 14                        NaN        Total  Total  Todas las edades     2022
#
#         Total
# 23  2.058.278
# 25    490.950
# 49    388.957
# 51  2.692.825
# 67    319.617
# 58  1.529.658
# 9     775.110
# 31     88.330
# 7   1.949.558
# 17  1.187.043
# 55    304.223
# 6   1.250.545
# 39  7.761.823
# 2   1.715.109
# 20  1.133.733
# 69     83.051
# 13    225.199
# 48  1.056.808
# 64    333.908
# 71     84.932
# 28    196.640
# 54    324.240
# 30    354.846
# 50    667.851
# 27    716.309
# 19  1.051.874
# 43    830.906
# 22    585.450
# 66    319.617
# 35    167.868
# 44  5.108.116
# 15  1.004.960
# 1   8.511.167
# 60    664.514
# 14  1.004.960

# %% [markdown]
# Eliminamos las columnas de Edad, Nacionalidad,Sexo y Periodo pues no interesan para el analisis. Los datos relevantes de estas categorías los obtenemos asociados a nivel educativo en otro archivo del INE.

# %%
# Eliminar las columnas 'Edad', 'Nacionalidad' y 'Sexo'
df_censo_2022.drop(columns=['Edad','Nacionalidad','Sexo','Periodo'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_censo_2022.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias       Total
# 0  Total Nacional                              NaN         NaN  47.486.727
# 1  Total Nacional                     01 Andalucía         NaN   8.511.167
# 2  Total Nacional                     01 Andalucía   29 Málaga   1.715.109
# 3  Total Nacional                     01 Andalucía     23 Jaén     624.191
# 4  Total Nacional                     01 Andalucía  04 Almería     739.541

# %% [markdown]
# Formatemaos la columna "Total"

# %%
# Convertimos la columna "Total" a int64
df_censo_2022['Total'] = df_censo_2022['Total'].str.replace('.', '').astype('int64')
df_censo_2022.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias     Total
# 0  Total Nacional                              NaN         NaN  47486727
# 1  Total Nacional                     01 Andalucía         NaN   8511167
# 2  Total Nacional                     01 Andalucía   29 Málaga   1715109
# 3  Total Nacional                     01 Andalucía     23 Jaén    624191
# 4  Total Nacional                     01 Andalucía  04 Almería    739541

# %% [markdown]
# A partir del DataFrame df_censo_2022 vamos a crear tres dataframes con la información a nivel nacional, autonómico y provincial respectivamente

# %%
def filtrar_dataframe_ine(df):
    """
    Filtra un DataFrame del ine en tres niveles: nacional, autonómico y provincial.

    Parámetros:
    df (pd.DataFrame): DataFrame que contiene las columnas 'Comunidades y Ciudades Autónomas' y 'Provincias'.

    Retorna:
    tuple: Tres DataFrames correspondientes a nivel nacional, autonómico y provincial.
    """
    # Nivel nacional: Filtramos donde "Comunidades y Ciudades Autónomas" sea NaN
    df_nacional = df[df['Comunidades y Ciudades Autónomas'].isna()].copy().reset_index(drop=True)

    # Nivel autonómico: Filtramos donde "Comunidades y Ciudades Autónomas" no sea NaN y "Provincias" sea NaN
    df_autonomico = df[df['Comunidades y Ciudades Autónomas'].notna() & df['Provincias'].isna()].copy().reset_index(drop=True)

    # Nivel provincial: Filtramos donde "Provincias" no sea NaN
    df_provincial = df[df['Provincias'].notna()].copy().reset_index(drop=True)

    return df_nacional, df_autonomico, df_provincial

# Lo aplicamos al DataFrame del censo de 2022:
df_censo_2022_nacional, df_censo_2022_autonomico, df_censo_2022_provincial = filtrar_dataframe_ine(df_censo_2022)

# %% [markdown]
# Verificamos que los dataframes filtrados se han creado correctamente

# %%
df_censo_2022_nacional.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias     Total
# 0  Total Nacional                              NaN        NaN  47486727

# %%
df_censo_2022_autonomico.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias    Total
# 0  Total Nacional                     01 Andalucía        NaN  8511167
# 1  Total Nacional                        02 Aragón        NaN  1328215
# 2  Total Nacional       03 Asturias, Principado de        NaN  1004960
# 3  Total Nacional                04 Balears, Illes        NaN  1187043
# 4  Total Nacional                      05 Canarias        NaN  2185607

# %%
df_censo_2022_provincial.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias    Total
# 0  Total Nacional                     01 Andalucía   29 Málaga  1715109
# 1  Total Nacional                     01 Andalucía     23 Jaén   624191
# 2  Total Nacional                     01 Andalucía  04 Almería   739541
# 3  Total Nacional                     01 Andalucía   21 Huelva   531094
# 4  Total Nacional                     01 Andalucía    11 Cádiz  1250545

# %% [markdown]
# # En primer lugar limpiamos los datos a nivel provincial

# %%
df_censo_2022_provincial.sample(20)
# Out:
#     Total Nacional Comunidades y Ciudades Autónomas  \
# 28  Total Nacional               07 Castilla y León
# 47  Total Nacional                    16 País Vasco
# 41  Total Nacional                       12 Galicia
# 37  Total Nacional                   11 Extremadura
# 15  Total Nacional                     06 Cantabria
# 35  Total Nacional          10 Comunitat Valenciana
# 6   Total Nacional                     01 Andalucía
# 2   Total Nacional                     01 Andalucía
# 46  Total Nacional                    16 País Vasco
# 50  Total Nacional                         18 Ceuta
# 24  Total Nacional               07 Castilla y León
# 10  Total Nacional                        02 Aragón
# 38  Total Nacional                   11 Extremadura
# 18  Total Nacional          08 Castilla - La Mancha
# 44  Total Nacional             14 Murcia, Región de
# 36  Total Nacional          10 Comunitat Valenciana
# 13  Total Nacional                      05 Canarias
# 1   Total Nacional                     01 Andalucía
# 11  Total Nacional       03 Asturias, Principado de
# 7   Total Nacional                     01 Andalucía
#
#                    Provincias    Total
# 28               37 Salamanca   326285
# 47             01 Araba/Álava   333908
# 41                    27 Lugo   324240
# 37                 10 Cáceres   388957
# 15               39 Cantabria   585450
# 35        03 Alicante/Alacant  1907494
# 6                  18 Granada   926019
# 2                  04 Almería   739541
# 46                 48 Bizkaia  1148677
# 50                   51 Ceuta    83051
# 24                34 Palencia   157993
# 10                  22 Huesca   225199
# 38                 06 Badajoz   667851
# 18                02 Albacete   385967
# 44                  30 Murcia  1529658
# 36      12 Castellón/Castelló   591300
# 13  38 Santa Cruz de Tenerife  1051874
# 1                     23 Jaén   624191
# 11                33 Asturias  1004960
# 7                  14 Córdoba   775110

# %%
def procesar_nivel_educativo_provincias(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel provincial, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Elimina la columna "Total Nacional".
    2. Separa los códigos y nombres de comunidades y provincias en columnas distintas.
    3. Convierte las columnas 'Código comunidad' y 'Código provincia' a tipo int64.
    4. Reordena las columnas colocando los códigos y nombres de comunidades y provincias al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar la columna "Total Nacional"
    if "Total Nacional" in df.columns:
        df.drop(columns=["Total Nacional"], inplace=True)
           
    # 2. Separar código y nombre de comunidad y provincia
    if 'Comunidades y Ciudades Autónomas' in df.columns and 'Provincias' in df.columns:
        df[['Código comunidad', 'Nombre comunidad']] = df['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)
        df[['Código provincia', 'Nombre provincia']] = df['Provincias'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Comunidades y Ciudades Autónomas', 'Provincias'], inplace=True)

    # 3. Convertir las columnas 'Código comunidad' y 'Código provincia' a tipo int64 si existen
    for col in ['Código comunidad', 'Código provincia']:
        if col in df.columns:
            df[col] = df[col].astype('int64')
    
    # 4. Reordenar las columnas para que los códigos y nombres aparezcan primero
    columnas_prioritarias = ['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_censo_2022_provincial = procesar_nivel_educativo_provincias(df_censo_2022_provincial)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_censo_2022_provincial.info())
df_censo_2022_provincial.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código comunidad  52 non-null     int64
#  1   Nombre comunidad  52 non-null     object
#  2   Código provincia  52 non-null     int64
#  3   Nombre provincia  52 non-null     object
#  4   Total             52 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB
# None
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                29           Málaga
# 1                 1        Andalucía                23             Jaén
# 2                 1        Andalucía                 4          Almería
# 3                 1        Andalucía                21           Huelva
# 4                 1        Andalucía                11            Cádiz
#
#      Total
# 0  1715109
# 1   624191
# 2   739541
# 3   531094
# 4  1250545

# %%
df_censo_2022_provincial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código comunidad  52 non-null     int64
#  1   Nombre comunidad  52 non-null     object
#  2   Código provincia  52 non-null     int64
#  3   Nombre provincia  52 non-null     object
#  4   Total             52 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %% [markdown]
# Ordenamos las filas del dataframe de acuerdo a la numeración de la columna "Código Comunidad"

# %%
df_censo_2022_provincial = df_censo_2022_provincial.sort_values(by="Código comunidad").reset_index(drop=True)

# %%
df_censo_2022_provincial
# Out:
#     Código comunidad             Nombre comunidad  Código provincia  \
# 0                  1                    Andalucía                29
# 1                  1                    Andalucía                23
# 2                  1                    Andalucía                 4
# 3                  1                    Andalucía                21
# 4                  1                    Andalucía                11
# 5                  1                    Andalucía                41
# 6                  1                    Andalucía                18
# 7                  1                    Andalucía                14
# 8                  2                       Aragón                50
# 9                  2                       Aragón                44
# 10                 2                       Aragón                22
# 11                 3      Asturias, Principado de                33
# 12                 4               Balears, Illes                 7
# 13                 5                     Canarias                38
# 14                 5                     Canarias                35
# 15                 6                    Cantabria                39
# 16                 7              Castilla y León                42
# 17                 7              Castilla y León                40
# 18                 7              Castilla y León                 9
# 19                 7              Castilla y León                37
# 20                 7              Castilla y León                47
# 21                 7              Castilla y León                49
# 22                 7              Castilla y León                 5
# 23                 7              Castilla y León                34
# 24                 7              Castilla y León                24
# 25                 8         Castilla - La Mancha                16
# 26                 8         Castilla - La Mancha                 2
# 27                 8         Castilla - La Mancha                45
# 28                 8         Castilla - La Mancha                19
# 29                 8         Castilla - La Mancha                13
# 30                 9                     Cataluña                25
# 31                 9                     Cataluña                17
# 32                 9                     Cataluña                 8
# 33                 9                     Cataluña                43
# 34                10         Comunitat Valenciana                46
# 35                10         Comunitat Valenciana                 3
# 36                10         Comunitat Valenciana                12
# 37                11                  Extremadura                10
# 38                11                  Extremadura                 6
# 39                12                      Galicia                36
# 40                12                      Galicia                15
# 41                12                      Galicia                27
# 42                12                      Galicia                32
# 43                13         Madrid, Comunidad de                28
# 44                14            Murcia, Región de                30
# 45                15  Navarra, Comunidad Foral de                31
# 46                16                   País Vasco                48
# 47                16                   País Vasco                 1
# 48                16                   País Vasco                20
# 49                17                    Rioja, La                26
# 50                18                        Ceuta                51
# 51                19                      Melilla                52
#
#           Nombre provincia    Total
# 0                   Málaga  1715109
# 1                     Jaén   624191
# 2                  Almería   739541
# 3                   Huelva   531094
# 4                    Cádiz  1250545
# 5                  Sevilla  1949558
# 6                  Granada   926019
# 7                  Córdoba   775110
# 8                 Zaragoza   968884
# 9                   Teruel   134132
# 10                  Huesca   225199
# 11                Asturias  1004960
# 12          Balears, Illes  1187043
# 13  Santa Cruz de Tenerife  1051874
# 14             Palmas, Las  1133733
# 15               Cantabria   585450
# 16                   Soria    88330
# 17                 Segovia   153731
# 18                  Burgos   354846
# 19               Salamanca   326285
# 20              Valladolid   518158
# 21                  Zamora   167868
# 22                   Ávila   159102
# 23                Palencia   157993
# 24                    León   449270
# 25                  Cuenca   196640
# 26                Albacete   385967
# 27                  Toledo   716309
# 28             Guadalajara   268412
# 29             Ciudad Real   490950
# 30                  Lleida   440883
# 31                  Girona   790432
# 32               Barcelona  5699602
# 33               Tarragona   830906
# 34       Valencia/València  2609322
# 35        Alicante/Alacant  1907494
# 36      Castellón/Castelló   591300
# 37                 Cáceres   388957
# 38                 Badajoz   667851
# 39              Pontevedra   945198
# 40               Coruña, A  1119164
# 41                    Lugo   324240
# 42                 Ourense   304223
# 43                  Madrid  6743254
# 44                  Murcia  1529658
# 45                 Navarra   664514
# 46                 Bizkaia  1148677
# 47             Araba/Álava   333908
# 48                Gipuzkoa   723241
# 49               Rioja, La   319617
# 50                   Ceuta    83051
# 51                 Melilla    84932

# %%
# Guardamos el DataFrame en un archivo CSV
df_censo_2022_provincial.to_csv("datos_limpiados/provincias/censo_2022_provincias_limpio.csv", index=False)

# %% [markdown]
# ## Limpiamos el dataframe con la información autonomica del censo

# %%
df_censo_2022_autonomico.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias    Total
# 0  Total Nacional                     01 Andalucía        NaN  8511167
# 1  Total Nacional                        02 Aragón        NaN  1328215
# 2  Total Nacional       03 Asturias, Principado de        NaN  1004960
# 3  Total Nacional                04 Balears, Illes        NaN  1187043
# 4  Total Nacional                      05 Canarias        NaN  2185607

# %% [markdown]
# Eliminamos la columna "Provincias que está vacía"

# %%
# Eliminar la columna 'Provincias'
df_censo_2022_autonomico.drop(columns=['Provincias'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_censo_2022_autonomico.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas    Total
# 0  Total Nacional                     01 Andalucía  8511167
# 1  Total Nacional                        02 Aragón  1328215
# 2  Total Nacional       03 Asturias, Principado de  1004960
# 3  Total Nacional                04 Balears, Illes  1187043
# 4  Total Nacional                      05 Canarias  2185607

# %%
def procesar_informacion_comunidades(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel de comunidad autónoma, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Elimina la columna "Total Nacional".
    2. Separa los códigos y nombres de comunidades en columnas distintas.
    3. Convierte la columna 'Código comunidad' a tipo int64.
    4. Reordena las columnas colocando los códigos y nombres de comunidades al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar la columna "Total Nacional"
    if "Total Nacional" in df.columns:
        df.drop(columns=["Total Nacional"], inplace=True)
           
    # 2. Separar código y nombre de comunidad
    if 'Comunidades y Ciudades Autónomas' in df.columns:
        df[['Código comunidad', 'Nombre comunidad']] = df['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Comunidades y Ciudades Autónomas'], inplace=True)

    # 3. Convertir la columnas 'Código comunidad' a tipo int64 si existe
    for col in ['Código comunidad']:
        if col in df.columns:
            df[col] = df[col].astype('int64')
    
    # 4. Reordenar las columnas para que el codigo y nombre de comunidad aparezcan primero
    columnas_prioritarias = ['Código comunidad', 'Nombre comunidad']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_censo_2022_autonomico = procesar_informacion_comunidades(df_censo_2022_autonomico)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_censo_2022_autonomico.info())
df_censo_2022_autonomico.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código comunidad  19 non-null     int64
#  1   Nombre comunidad  19 non-null     object
#  2   Total             19 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 588.0+ bytes
# None
#    Código comunidad         Nombre comunidad    Total
# 0                 1                Andalucía  8511167
# 1                 2                   Aragón  1328215
# 2                 3  Asturias, Principado de  1004960
# 3                 4           Balears, Illes  1187043
# 4                 5                 Canarias  2185607

# %% [markdown]
# Ordenamos las filas del dataframe de acuerdo a la numeración de la columna "Código Comunidad"

# %%
df_censo_2022_autonomico = df_censo_2022_autonomico.sort_values(by="Código comunidad").reset_index(drop=True)
df_censo_2022_autonomico
# Out:
#     Código comunidad             Nombre comunidad    Total
# 0                  1                    Andalucía  8511167
# 1                  2                       Aragón  1328215
# 2                  3      Asturias, Principado de  1004960
# 3                  4               Balears, Illes  1187043
# 4                  5                     Canarias  2185607
# 5                  6                    Cantabria   585450
# 6                  7              Castilla y León  2375583
# 7                  8         Castilla - La Mancha  2058278
# 8                  9                     Cataluña  7761823
# 9                 10         Comunitat Valenciana  5108116
# 10                11                  Extremadura  1056808
# 11                12                      Galicia  2692825
# 12                13         Madrid, Comunidad de  6743254
# 13                14            Murcia, Región de  1529658
# 14                15  Navarra, Comunidad Foral de   664514
# 15                16                   País Vasco  2205826
# 16                17                    Rioja, La   319617
# 17                18                        Ceuta    83051
# 18                19                      Melilla    84932

# %%
# Guardamos el DataFrame en un archivo CSV
df_censo_2022_autonomico.to_csv("datos_limpiados/comunidades/censo_2022_autonomico_limpio.csv", index=False)

# %% [markdown]
# Procesamos y limipamos el dataframe con la informaciónnacional del censo

# %%
def procesar_informacion_nacional(df):
    """
    Realiza el procesamiento de un DataFrame con información a nivel nacional, extraída del INE,
    aplicando las siguientes transformaciones:

    1. Elimina las columnas 'Provincias' y 'Comunidades y Ciudades Autónomas'.
    2. Renombra la columna "Total Nacional" a "Nombre del país".
    3. Asigna el valor "España" a todas las filas en la columna "Nombre del país".
        
    Parámetros:
    -----------
        df (pd.DataFrame): DataFrame con la información de nivel educativo a nivel nacional.

    Retorna:
    --------
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar las columnas 'Provincias' y 'Comunidades y Ciudades Autónomas' si existen
    columnas_a_eliminar = ['Comunidades y Ciudades Autónomas', 'Provincias']
    df.drop(columns=[col for col in columnas_a_eliminar if col in df.columns], inplace=True)

    # 2. Renombrar la columna "Total Nacional" a "Nombre del país" si existe
    if "Total Nacional" in df.columns:
        df.rename(columns={"Total Nacional": "Nombre del país"}, inplace=True)

    # 3. Asignar el valor "España" a todas las filas en la columna "Nombre del país"
    if "Nombre del país" in df.columns:
        df["Nombre del país"] = "España"

    return df

# Aplicar la función al DataFrame
df_censo_2022_nacional = procesar_informacion_nacional(df_censo_2022_nacional)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_censo_2022_nacional.info())
df_censo_2022_nacional.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre del país  1 non-null      object
#  1   Total            1 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 148.0+ bytes
# None
#   Nombre del país     Total
# 0          España  47486727

# %%
# Guardamos el DataFrame en un archivo CSV
df_censo_2022_nacional.to_csv("datos_limpiados/nacionales/censo_2022_nacional_limpio.csv", index=False)

# %% [markdown]
# ## Ahora limpiamos los datos del censo para municipios

# %%
df_censo_2022_municipios = pd.read_csv("datos/ine/censo_2022_municipios.csv", encoding= 'latin-1', sep=';')

# %%
df_censo_2022_municipios.head()
# Out:
#    Total Nacional      Provincias              Municipios   Sexo  \
# 0  Total Nacional  01 Araba/Álava                     NaN  Total
# 1  Total Nacional  01 Araba/Álava  01001 Alegría-Dulantzi  Total
# 2  Total Nacional  01 Araba/Álava           01002 Amurrio  Total
# 3  Total Nacional  01 Araba/Álava           01003 Aramaio  Total
# 4  Total Nacional  01 Araba/Álava        01004 Artziniega  Total
#
#                Edad Lugar de nacimiento  Periodo    Total
# 0  Todas las edades               Total     2022  333.908
# 1  Todas las edades               Total     2022    2.969
# 2  Todas las edades               Total     2022   10.265
# 3  Todas las edades               Total     2022    1.429
# 4  Todas las edades               Total     2022    1.809

# %%
df_censo_2022_municipios.sample(20)
# Out:
#       Total Nacional             Provincias  \
# 5081  Total Nacional            33 Asturias
# 1921  Total Nacional  12 Castellón/Castelló
# 2647  Total Nacional              17 Girona
# 6788  Total Nacional              44 Teruel
# 5254  Total Nacional            34 Palencia
# 676   Total Nacional             06 Badajoz
# 3184  Total Nacional            20 Gipuzkoa
# 7419  Total Nacional          47 Valladolid
# 6133  Total Nacional             41 Sevilla
# 2539  Total Nacional              17 Girona
# 1845  Total Nacional  12 Castellón/Castelló
# 2922  Total Nacional         19 Guadalajara
# 3022  Total Nacional         19 Guadalajara
# 962   Total Nacional           08 Barcelona
# 1508  Total Nacional              09 Burgos
# 4265  Total Nacional                27 Lugo
# 4410  Total Nacional              28 Madrid
# 2336  Total Nacional              16 Cuenca
# 3034  Total Nacional         19 Guadalajara
# 6216  Total Nacional             41 Sevilla
#
#                              Municipios   Sexo              Edad  \
# 5081                      33068 Somiedo  Total  Todas las edades
# 1921                12107 Sot de Ferrer  Total  Todas las edades
# 2647  17187 Saus, Camallera i Llampaies  Total  Todas las edades
# 6788             44225 Torre del Compte  Total  Todas las edades
# 5254                    34216 Villalcón  Total  Todas las edades
# 676                      06041 Cristina  Total  Todas las edades
# 3184                       20025 Zegama  Total  Todas las edades
# 7419                        47126 Puras  Total  Todas las edades
# 6133                        41021 Camas  Total  Todas las edades
# 2539                  17070 Fontanilles  Total  Todas las edades
# 1845                      12024 Benafer  Total  Todas las edades
# 2922                 19061 Campisábalos  Total  Todas las edades
# 3022                      19184 Millana  Total  Todas las edades
# 962                    08093 Gisclareny  Total  Todas las edades
# 1508    09431 Villafranca Montes de Oca  Total  Todas las edades
# 4265                     27016 Chantada  Total  Todas las edades
# 4410                28095 Navalagamella  Total  Todas las edades
# 2336        16115 Laguna del Marquesado  Total  Todas las edades
# 3034                       19196 Muduex  Total  Todas las edades
# 6216                   41902 Isla Mayor  Total  Todas las edades
#
#      Lugar de nacimiento  Periodo   Total
# 5081               Total     2022   1.109
# 1921               Total     2022     449
# 2647               Total     2022     881
# 6788               Total     2022     123
# 5254               Total     2022      58
# 676                Total     2022     558
# 3184               Total     2022   1.535
# 7419               Total     2022      44
# 6133               Total     2022  27.470
# 2539               Total     2022     163
# 1845               Total     2022     173
# 2922               Total     2022      67
# 3022               Total     2022     118
# 962                Total     2022      28
# 1508               Total     2022     116
# 4265               Total     2022   8.064
# 4410               Total     2022   2.844
# 2336               Total     2022      56
# 3034               Total     2022     106
# 6216               Total     2022   5.748

# %%
df_censo_2022_municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8184 entries, 0 to 8183
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Total Nacional       8184 non-null   object
#  1   Provincias           8184 non-null   object
#  2   Municipios           8132 non-null   object
#  3   Sexo                 8184 non-null   object
#  4   Edad                 8184 non-null   object
#  5   Lugar de nacimiento  8184 non-null   object
#  6   Periodo              8184 non-null   int64
#  7   Total                8183 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 511.6+ KB

# %% [markdown]
# La columna "Total" tiene un nulo que vamos a identificar y decidir como lo tratamos

# %%
# Identificar la fila donde la columna "Total" tiene un valor nulo
fila_nula = df_censo_2022_municipios[df_censo_2022_municipios['Total'].isnull()]
fila_nula
# Out:
#       Total Nacional  Provincias      Municipios   Sexo              Edad  \
# 7636  Total Nacional  48 Bizkaia  48916 Usansolo  Total  Todas las edades
#
#      Lugar de nacimiento  Periodo Total
# 7636               Total     2022   NaN

# %% [markdown]
# En la web del INE de donde se descargaron los datos comprobamos que efectivamente el valor de Población total para este municipio. falta tanto para el 2022 como también el 2021 y 2023. Para 2024 si está disponible, así que lo imputamos por el valor extraido de la web del INE para el año 2024

# %%
# Imputar el valor nulo con 4.568 en la columna "Total"
df_censo_2022_municipios.loc[df_censo_2022_municipios['Total'].isnull(), 'Total'] = "4.568"

# Verificar que la imputación se realizó correctamente
df_censo_2022_municipios.loc[7636]
# Out:
# Total Nacional           Total Nacional
# Provincias                   48 Bizkaia
# Municipios               48916 Usansolo
# Sexo                              Total
# Edad                   Todas las edades
# Lugar de nacimiento               Total
# Periodo                            2022
# Total                             4.568
# Name: 7636, dtype: object

# %% [markdown]
# Formateamos la columna "Total"

# %%
# Convertimos la columna "Total" a int64
df_censo_2022_municipios['Total'] = df_censo_2022_municipios['Total'].str.replace('.', '').astype('int64')
df_censo_2022_municipios.head()
# Out:
#    Total Nacional      Provincias              Municipios   Sexo  \
# 0  Total Nacional  01 Araba/Álava                     NaN  Total
# 1  Total Nacional  01 Araba/Álava  01001 Alegría-Dulantzi  Total
# 2  Total Nacional  01 Araba/Álava           01002 Amurrio  Total
# 3  Total Nacional  01 Araba/Álava           01003 Aramaio  Total
# 4  Total Nacional  01 Araba/Álava        01004 Artziniega  Total
#
#                Edad Lugar de nacimiento  Periodo   Total
# 0  Todas las edades               Total     2022  333908
# 1  Todas las edades               Total     2022    2969
# 2  Todas las edades               Total     2022   10265
# 3  Todas las edades               Total     2022    1429
# 4  Todas las edades               Total     2022    1809

# %% [markdown]
# Identificamos ahora los nulos de la columna "Municipios"

# %%
filas_nulas = df_censo_2022_municipios[df_censo_2022_municipios['Municipios'].isnull()]
filas_nulas
# Out:
#       Total Nacional                 Provincias Municipios   Sexo  \
# 0     Total Nacional             01 Araba/Álava        NaN  Total
# 52    Total Nacional                02 Albacete        NaN  Total
# 140   Total Nacional        03 Alicante/Alacant        NaN  Total
# 282   Total Nacional                 04 Almería        NaN  Total
# 386   Total Nacional                   05 Ávila        NaN  Total
# 635   Total Nacional                 06 Badajoz        NaN  Total
# 801   Total Nacional          07 Balears, Illes        NaN  Total
# 869   Total Nacional               08 Barcelona        NaN  Total
# 1181  Total Nacional                  09 Burgos        NaN  Total
# 1553  Total Nacional                 10 Cáceres        NaN  Total
# 1777  Total Nacional                   11 Cádiz        NaN  Total
# 1823  Total Nacional      12 Castellón/Castelló        NaN  Total
# 1959  Total Nacional             13 Ciudad Real        NaN  Total
# 2062  Total Nacional                 14 Córdoba        NaN  Total
# 2140  Total Nacional               15 Coruña, A        NaN  Total
# 2234  Total Nacional                  16 Cuenca        NaN  Total
# 2473  Total Nacional                  17 Girona        NaN  Total
# 2695  Total Nacional                 18 Granada        NaN  Total
# 2870  Total Nacional             19 Guadalajara        NaN  Total
# 3159  Total Nacional                20 Gipuzkoa        NaN  Total
# 3248  Total Nacional                  21 Huelva        NaN  Total
# 3329  Total Nacional                  22 Huesca        NaN  Total
# 3532  Total Nacional                    23 Jaén        NaN  Total
# 3630  Total Nacional                    24 León        NaN  Total
# 3842  Total Nacional                  25 Lleida        NaN  Total
# 4074  Total Nacional               26 Rioja, La        NaN  Total
# 4249  Total Nacional                    27 Lugo        NaN  Total
# 4317  Total Nacional                  28 Madrid        NaN  Total
# 4497  Total Nacional                  29 Málaga        NaN  Total
# 4601  Total Nacional                  30 Murcia        NaN  Total
# 4647  Total Nacional                 31 Navarra        NaN  Total
# 4920  Total Nacional                 32 Ourense        NaN  Total
# 5013  Total Nacional                33 Asturias        NaN  Total
# 5092  Total Nacional                34 Palencia        NaN  Total
# 5284  Total Nacional             35 Palmas, Las        NaN  Total
# 5319  Total Nacional              36 Pontevedra        NaN  Total
# 5381  Total Nacional               37 Salamanca        NaN  Total
# 5744  Total Nacional  38 Santa Cruz de Tenerife        NaN  Total
# 5799  Total Nacional               39 Cantabria        NaN  Total
# 5902  Total Nacional                 40 Segovia        NaN  Total
# 6112  Total Nacional                 41 Sevilla        NaN  Total
# 6219  Total Nacional                   42 Soria        NaN  Total
# 6403  Total Nacional               43 Tarragona        NaN  Total
# 6588  Total Nacional                  44 Teruel        NaN  Total
# 6825  Total Nacional                  45 Toledo        NaN  Total
# 7030  Total Nacional       46 Valencia/València        NaN  Total
# 7297  Total Nacional              47 Valladolid        NaN  Total
# 7523  Total Nacional                 48 Bizkaia        NaN  Total
# 7637  Total Nacional                  49 Zamora        NaN  Total
# 7886  Total Nacional                50 Zaragoza        NaN  Total
# 8180  Total Nacional                   51 Ceuta        NaN  Total
# 8182  Total Nacional                 52 Melilla        NaN  Total
#
#                   Edad Lugar de nacimiento  Periodo    Total
# 0     Todas las edades               Total     2022   333908
# 52    Todas las edades               Total     2022   385967
# 140   Todas las edades               Total     2022  1907494
# 282   Todas las edades               Total     2022   739541
# 386   Todas las edades               Total     2022   159102
# 635   Todas las edades               Total     2022   667851
# 801   Todas las edades               Total     2022  1187043
# 869   Todas las edades               Total     2022  5699602
# 1181  Todas las edades               Total     2022   354846
# 1553  Todas las edades               Total     2022   388957
# 1777  Todas las edades               Total     2022  1250545
# 1823  Todas las edades               Total     2022   591300
# 1959  Todas las edades               Total     2022   490950
# 2062  Todas las edades               Total     2022   775110
# 2140  Todas las edades               Total     2022  1119164
# 2234  Todas las edades               Total     2022   196640
# 2473  Todas las edades               Total     2022   790432
# 2695  Todas las edades               Total     2022   926019
# 2870  Todas las edades               Total     2022   268412
# 3159  Todas las edades               Total     2022   723241
# 3248  Todas las edades               Total     2022   531094
# 3329  Todas las edades               Total     2022   225199
# 3532  Todas las edades               Total     2022   624191
# 3630  Todas las edades               Total     2022   449270
# 3842  Todas las edades               Total     2022   440883
# 4074  Todas las edades               Total     2022   319617
# 4249  Todas las edades               Total     2022   324240
# 4317  Todas las edades               Total     2022  6743254
# 4497  Todas las edades               Total     2022  1715109
# 4601  Todas las edades               Total     2022  1529658
# 4647  Todas las edades               Total     2022   664514
# 4920  Todas las edades               Total     2022   304223
# 5013  Todas las edades               Total     2022  1004960
# 5092  Todas las edades               Total     2022   157993
# 5284  Todas las edades               Total     2022  1133733
# 5319  Todas las edades               Total     2022   945198
# 5381  Todas las edades               Total     2022   326285
# 5744  Todas las edades               Total     2022  1051874
# 5799  Todas las edades               Total     2022   585450
# 5902  Todas las edades               Total     2022   153731
# 6112  Todas las edades               Total     2022  1949558
# 6219  Todas las edades               Total     2022    88330
# 6403  Todas las edades               Total     2022   830906
# 6588  Todas las edades               Total     2022   134132
# 6825  Todas las edades               Total     2022   716309
# 7030  Todas las edades               Total     2022  2609322
# 7297  Todas las edades               Total     2022   518158
# 7523  Todas las edades               Total     2022  1148677
# 7637  Todas las edades               Total     2022   167868
# 7886  Todas las edades               Total     2022   968884
# 8180  Todas las edades               Total     2022    83051
# 8182  Todas las edades               Total     2022    84932

# %% [markdown]
# Vemos que corresponden a datos nacionales y de provincias, ya tratados en otro dataframe, así pues los eliminamos de este.

# %%
# Eliminar las filas donde la columna "Municipios" tiene valores nulos
df_censo_2022_municipios = df_censo_2022_municipios.dropna(subset=['Municipios']).reset_index(drop=True)

# Mostrar el DataFrame actualizado
df_censo_2022_municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8132 entries, 0 to 8131
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Total Nacional       8132 non-null   object
#  1   Provincias           8132 non-null   object
#  2   Municipios           8132 non-null   object
#  3   Sexo                 8132 non-null   object
#  4   Edad                 8132 non-null   object
#  5   Lugar de nacimiento  8132 non-null   object
#  6   Periodo              8132 non-null   int64
#  7   Total                8132 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 508.4+ KB

# %% [markdown]
# Eliminamos las columnas "Total Nacional", "Sexo", "Edad", "Lugar de nacimiento" y "Periodo" pues sol buscamos de este dataframe el quedarnos con los datos de Población Total.

# %%
# Eliminar las columnas 'Total Nacional', 'Edad', 'Nacionalidad' y 'Sexo'
df_censo_2022_municipios.drop(columns=['Total Nacional','Edad','Lugar de nacimiento','Sexo','Periodo'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_censo_2022_municipios.head()
# Out:
#        Provincias              Municipios  Total
# 0  01 Araba/Álava  01001 Alegría-Dulantzi   2969
# 1  01 Araba/Álava           01002 Amurrio  10265
# 2  01 Araba/Álava           01003 Aramaio   1429
# 3  01 Araba/Álava        01004 Artziniega   1809
# 4  01 Araba/Álava           01006 Armiñón    235

# %% [markdown]
# Vamos a separar la parte numerica de la columna Provincias y a guardarla como código en una nueva columna que creamos.

# %%
# Separar código y nombre de las provincias         
if 'Provincias' in df_censo_2022_municipios.columns:
    df_censo_2022_municipios[['Código provincia', 'Nombre provincia']] = df_censo_2022_municipios['Provincias'].str.split(pat=' ', n=1, expand=True)
    df_censo_2022_municipios.drop(columns=['Provincias'], inplace=True)
    
# Convertir la columna 'Código provincia' a tipo int64 si existe
if 'Código provincia' in df_censo_2022_municipios.columns:
    df_censo_2022_municipios['Código provincia'] = df_censo_2022_municipios['Código provincia'].astype('int64')

# Reordenar las columnas para que el código y nombre de provincia aparezcan primero
columnas_prioritarias = ['Código provincia', 'Nombre provincia']
columnas_ordenadas = columnas_prioritarias + [col for col in df_censo_2022_municipios.columns if col not in columnas_prioritarias]
df_censo_2022_municipios = df_censo_2022_municipios[columnas_ordenadas]

# Mostrar información y primeras filas del DataFrame actualizado
print(df_censo_2022_municipios.info())
df_censo_2022_municipios.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8132 entries, 0 to 8131
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código provincia  8132 non-null   int64
#  1   Nombre provincia  8132 non-null   object
#  2   Municipios        8132 non-null   object
#  3   Total             8132 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 254.3+ KB
# None
#    Código provincia Nombre provincia              Municipios  Total
# 0                 1      Araba/Álava  01001 Alegría-Dulantzi   2969
# 1                 1      Araba/Álava           01002 Amurrio  10265
# 2                 1      Araba/Álava           01003 Aramaio   1429
# 3                 1      Araba/Álava        01004 Artziniega   1809
# 4                 1      Araba/Álava           01006 Armiñón    235

# %% [markdown]
# Proesamos el dataframe con una función creada para limpiar dataframes con información municipal del INE.

# %%
def procesar_informacion_municipios(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel municipal, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Separa los códigos y nombres de comunidades y provincias en columnas distintas.
    2. Convierte las columnas 'Código comunidad' y 'Código provincia' a tipo int64.
    3. Reordena las columnas colocando los códigos y nombres de comunidades y provincias al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
        
    # 1. Separar código y nombre de los municipios         
    if 'Municipios' in df.columns:
        df[['Código municipio', 'Nombre municipio']] = df['Municipios'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Municipios'], inplace=True)
        
    # 2. Convertir la columna 'Código municipio' a tipo int64 si existe
    if 'Código municipio' in df.columns:
        df['Código municipio'] = df['Código municipio'].astype('int64')
    
    # 3. Reordenar las columnas para que los códigos y nombres aparezcan primero
    columnas_prioritarias = ['Código municipio', 'Nombre municipio']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_censo_2022_municipios = procesar_informacion_municipios(df_censo_2022_municipios)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_censo_2022_municipios.info())
df_censo_2022_municipios.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8132 entries, 0 to 8131
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Código municipio  8132 non-null   int64
#  1   Nombre municipio  8132 non-null   object
#  2   Código provincia  8132 non-null   int64
#  3   Nombre provincia  8132 non-null   object
#  4   Total             8132 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 317.8+ KB
# None
#    Código municipio  Nombre municipio  Código provincia Nombre provincia  \
# 0              1001  Alegría-Dulantzi                 1      Araba/Álava
# 1              1002           Amurrio                 1      Araba/Álava
# 2              1003           Aramaio                 1      Araba/Álava
# 3              1004        Artziniega                 1      Araba/Álava
# 4              1006           Armiñón                 1      Araba/Álava
#
#    Total
# 0   2969
# 1  10265
# 2   1429
# 3   1809
# 4    235

# %%
# Guardamos el DataFrame en un archivo CSV
df_censo_2022_municipios.to_csv("datos_limpiados/municipios/censo_2022_municipal_limpio.csv", index=False)
