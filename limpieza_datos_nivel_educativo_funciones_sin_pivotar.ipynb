# %%
# Para trabajar con regex
# -----------------------------------------------------------------------
import re

# Para trabajar con ficheros
# -----------------------------------------------------------------------
import os


# Para trabajar con los DataFrames
# -----------------------------------------------------------------------
import pandas as pd

# Para poner barras progreso
# -----------------------------------------------------------------------
from tqdm import tqdm



# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Ignorar warings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# Librerias para generar gráficas
# ----------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# En este notebook se limpian los archivos de nivel educativivo alcanzado extraidos del INE. Por un lado se tratan los municipios (grandes y pequeños) y por otro las provincias, comunidades y total de país, pues provienen de archivos distintos.

# %% [markdown]
# ## Limpiamos y concatenamos los dataframes de nivel educativo de municipios pequeños (de 50 a 500 habitantes) y grandes (más de 500 habitantes)

# %%
df_nivel_educativo_municipios_pequenios = pd.read_csv("datos/ine/nivel_educativo_municipios_pequenios.csv",sep=';')

# %%
df_nivel_educativo_municipios_pequenios.head()
# Out:
#       Municipios   Sexo                                Nivel de estudios  \
# 0  01006 Armiñón  Total                                            Total
# 1  01006 Armiñón  Total                                            Total
# 2  01006 Armiñón  Total                    Educación primaria e inferior
# 3  01006 Armiñón  Total                    Educación primaria e inferior
# 4  01006 Armiñón  Total  Primera etapa de educación secundaria y similar
#
#    Periodo  Total
# 0     2022    205
# 1     2021    198
# 2     2022     18
# 3     2021     17
# 4     2022     55

# %%
df_nivel_educativo_municipios_grandes = pd.read_csv("datos/ine/nivel_educativo_municipios_grandes.csv",sep=';')

# %%
df_nivel_educativo_municipios_grandes.head(20)
# Out:
#                 Municipios   Sexo País de nacimiento  \
# 0   01001 Alegría-Dulantzi  Total              Total
# 1   01001 Alegría-Dulantzi  Total              Total
# 2   01001 Alegría-Dulantzi  Total              Total
# 3   01001 Alegría-Dulantzi  Total              Total
# 4   01001 Alegría-Dulantzi  Total              Total
# 5   01001 Alegría-Dulantzi  Total              Total
# 6   01001 Alegría-Dulantzi  Total              Total
# 7   01001 Alegría-Dulantzi  Total              Total
# 8   01001 Alegría-Dulantzi  Total              Total
# 9   01001 Alegría-Dulantzi  Total              Total
# 10  01001 Alegría-Dulantzi  Total              Total
# 11  01001 Alegría-Dulantzi  Total              Total
# 12  01001 Alegría-Dulantzi  Total              Total
# 13  01001 Alegría-Dulantzi  Total              Total
# 14  01001 Alegría-Dulantzi  Total              Total
# 15  01001 Alegría-Dulantzi  Total              Total
# 16  01001 Alegría-Dulantzi  Total              Total
# 17  01001 Alegría-Dulantzi  Total              Total
# 18  01001 Alegría-Dulantzi  Total              Total
# 19  01001 Alegría-Dulantzi  Total              Total
#
#                                     Nivel de estudios  Periodo  Total
# 0                                               Total     2022  2.428
# 1                                               Total     2021  2.369
# 2                                        Sin estudios     2022     75
# 3                                        Sin estudios     2021     76
# 4                                  Educación primaria     2022    202
# 5                                  Educación primaria     2021    191
# 6     Primera etapa de educación secundaria y similar     2022    617
# 7     Primera etapa de educación secundaria y similar     2021    599
# 8   Segunda etapa de educación secundaria, con ori...     2022    232
# 9   Segunda etapa de educación secundaria, con ori...     2021    236
# 10  Segunda etapa de educación secundaria con orie...     2022    269
# 11  Segunda etapa de educación secundaria con orie...     2021    265
# 12  Enseñanzas de formación profesional, artes plá...     2022    495
# 13  Enseñanzas de formación profesional, artes plá...     2021    483
# 14  Grados universitarios de hasta 240 créditos EC...     2022    257
# 15  Grados universitarios de hasta 240 créditos EC...     2021    248
# 16  Grados universitarios de más de 240 créditos E...     2022    226
# 17  Grados universitarios de más de 240 créditos E...     2021    228
# 18  Másteres, especialidades en Ciencias de la Sal...     2022     44
# 19  Másteres, especialidades en Ciencias de la Sal...     2021     33

# %%
df_nivel_educativo_municipios_grandes.sample(20)
# Out:
#                            Municipios     Sexo País de nacimiento  \
# 210218                 13010 Alhambra  Mujeres              Total
# 714409                  45163 Sonseca    Total         Extranjera
# 368918           22907 Aínsa-Sobrarbe    Total             España
# 497457      29098 Villanueva de Tapia  Hombres              Total
# 154301  09131 Fresnillo de las Dueñas    Total             España
# 651365                 41085 Salteras  Mujeres              Total
# 408409                24228 Villazala  Mujeres              Total
# 421733    25158 Palau d'Anglesola, El  Mujeres             España
# 549774                     33007 Boal  Hombres             España
# 441530        27017 Folgoso do Courel  Mujeres             España
# 385158                  23094 Vilches    Total             España
# 536197                32027 Cortegada    Total              Total
# 272032                    17027 Breda  Mujeres             España
# 20934          03014 Alacant/Alicante  Mujeres              Total
# 700494               45066 Fuensalida  Mujeres         Extranjera
# 6569                  02001 Abengibre    Total         Extranjera
# 76513      06090 Nava de Santiago, La  Hombres              Total
# 181654     10188 Torre de Santa María  Hombres         Extranjera
# 338079                     20045 Irun  Hombres         Extranjera
# 689676         44201 Rubielos de Mora    Total         Extranjera
#
#                                         Nivel de estudios  Periodo  Total
# 210218  Segunda etapa de educación secundaria, con ori...     2022   22.0
# 714409                                       Sin estudios     2021  137.0
# 368918                                              Total     2022  1.433
# 497457  Grados universitarios de hasta 240 créditos EC...     2021     33
# 154301  Grados universitarios de hasta 240 créditos EC...     2021   59.0
# 651365  Segunda etapa de educación secundaria con orie...     2021  281.0
# 408409                                              Total     2021    284
# 421733  Grados universitarios de hasta 240 créditos EC...     2021    114
# 549774  Grados universitarios de más de 240 créditos E...     2022   17.0
# 441530  Enseñanzas de formación profesional, artes plá...     2022     35
# 385158                                 Educación primaria     2022  364.0
# 536197  Enseñanzas de formación profesional, artes plá...     2021   70.0
# 272032                                       Sin estudios     2022   31.0
# 20934   Enseñanzas de formación profesional, artes plá...     2022  9.875
# 700494  Grados universitarios de hasta 240 créditos EC...     2022   64.0
# 6569    Enseñanzas de formación profesional, artes plá...     2021      0
# 76513   Másteres, especialidades en Ciencias de la Sal...     2021      0
# 181654                                              Total     2022    6.0
# 338079                                 Educación primaria     2021  506.0
# 689676                            Doctorado universitario     2022    0.0

# %%
df_nivel_estudios_en_curso_por_lugar = pd.read_csv("datos/ine/nivel_estudios_en_curso_por_lugar.csv",sep=';')

# %%
df_nivel_estudios_en_curso_por_lugar.sample(20)
# Out:
#             Capitales y grandes ciudades     Sexo  \
# 34414        08266 Cerdanyola del Vallès    Total
# 20529                    08019 Barcelona  Hombres
# 53251                    15030 Coruña, A  Mujeres
# 92485   28134 San Sebastián de los Reyes  Mujeres
# 75560                     28013 Aranjuez  Mujeres
# 32523        08205 Sant Cugat del Vallès    Total
# 88038                        28113 Pinto  Hombres
# 140313                     46190 Paterna    Total
# 118954                  36038 Pontevedra    Total
# 19754                     08015 Badalona  Hombres
# 112917                    34120 Palencia    Total
# 133670                       42173 Soria  Hombres
# 85213                  28080 Majadahonda  Hombres
# 86716                        28106 Parla    Total
# 97141                   29054 Fuengirola  Hombres
# 92742            28148 Torrejón de Ardoz    Total
# 19620                     08015 Badalona  Hombres
# 76176              28014 Arganda del Rey  Hombres
# 19462                     08015 Badalona    Total
# 127134                 39087 Torrelavega    Total
#
#        Relación entre lugar de residencia y lugar de estudios Nacionalidad  \
# 34414            Distinto municipio de la misma provincia       Extranjera
# 20529                                               Total       Extranjera
# 53251            Distinta provincia de la misma comunidad         Española
# 92485                    Mismo municipio al de residencia       Extranjera
# 75560                                   No cursa estudios            Total
# 32523   Cursa estudios pero no hay información sobre e...         Española
# 88038                                               Total            Total
# 140313                                 Distinta comunidad            Total
# 118954                                              Total            Total
# 19754   Cursa estudios pero no hay información sobre e...         Española
# 112917                                              Total         Española
# 133670  Cursa estudios pero no hay información sobre e...       Extranjera
# 85213                                  Distinta comunidad            Total
# 86716                                               Total         Española
# 97141                                               Total       Extranjera
# 92742                                               Total            Total
# 19620            Distinto municipio de la misma provincia       Extranjera
# 76176   Cursa estudios pero no hay información sobre e...            Total
# 19462                                   No cursa estudios         Española
# 127134           Distinto municipio de la misma provincia         Española
#
#                                Nivel de estudios en curso  Periodo    Total
# 34414   Cursa estudios pero no hay información sobre l...     2022        1
# 20529                                               Total     2021  151.893
# 53251                       Educación primaria e inferior     2021        0
# 92485     Primera etapa de Educación Secundaria y similar     2021       44
# 75560   Segunda etapa de Educación Secundaria, con ori...     2022        0
# 32523                                  Educación superior     2021      691
# 88038   Segunda etapa de educación secundaria, con ori...     2022      758
# 140313  Segunda etapa de Educación Secundaria, con ori...     2021     24.0
# 118954                                 Educación superior     2022    4.192
# 19754                                  Educación superior     2022      325
# 112917    Primera etapa de Educación Secundaria y similar     2021      331
# 133670  Segunda etapa de educación secundaria, con ori...     2022      1.0
# 85213                                   No cursa estudios     2021        0
# 86716                                   No cursa estudios     2022   73.626
# 97141     Primera etapa de Educación Secundaria y similar     2021       62
# 92742   Segunda etapa de educación secundaria, con ori...     2022    3.407
# 19620     Primera etapa de Educación Secundaria y similar     2022       30
# 76176                                               Total     2022      111
# 19462   Segunda etapa de educación secundaria, con ori...     2022        0
# 127134  Cursa estudios pero no hay información sobre l...     2022        3

# %%
df_nivel_educativo_municipios_pequenios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102570 entries, 0 to 102569
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Municipios         102570 non-null  object
#  1   Sexo               102570 non-null  object
#  2   Nivel de estudios  102570 non-null  object
#  3   Periodo            102570 non-null  int64
#  4   Total              102570 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 3.9+ MB

# %%
df_nivel_educativo_municipios_grandes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820512 entries, 0 to 820511
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Municipios          820512 non-null  object
#  1   Sexo                820512 non-null  object
#  2   País de nacimiento  820512 non-null  object
#  3   Nivel de estudios   820512 non-null  object
#  4   Periodo             820512 non-null  int64
#  5   Total               820512 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 37.6+ MB

# %% [markdown]
# Formateamos la columna "Total"

# %%
# Eliminar caracteres no numéricos y convertir la columna 'Total' a entero
df_nivel_educativo_municipios_grandes['Total'] = (
    df_nivel_educativo_municipios_grandes['Total']
    .astype(str)  # Convertir a string para realizar operaciones
    .str.replace(r'[^\d]', '', regex=True)  # Eliminar caracteres no numéricos
    .astype(int)  # Convertir a entero
)

# Confirmar el cambio mostrando las primeras filas
df_nivel_educativo_municipios_grandes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820512 entries, 0 to 820511
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Municipios          820512 non-null  object
#  1   Sexo                820512 non-null  object
#  2   País de nacimiento  820512 non-null  object
#  3   Nivel de estudios   820512 non-null  object
#  4   Periodo             820512 non-null  int64
#  5   Total               820512 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 37.6+ MB

# %% [markdown]
# Queremos juntar los datos de nivel educativo alcanzado en un solo dataframe.

# %%
unique_grandes = df_nivel_educativo_municipios_grandes["Nivel de estudios"].unique()
unique_pequenios = df_nivel_educativo_municipios_pequenios["Nivel de estudios"].unique()

unique_grandes, unique_pequenios
# Out:
# (array(['Total', 'Sin estudios', 'Educación primaria',
#         'Primera etapa de educación secundaria y similar',
#         'Segunda etapa de educación secundaria, con orientación general',
#         'Segunda etapa de educación secundaria con orientación profesional, Educación postsecundaria no superior',
#         'Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes',
#         'Grados universitarios de hasta 240 créditos ECTS, diplomados universitarios y equivalentes',
#         'Grados universitarios de más de 240 créditos ECTS, licenciados y equivalentes',
#         'Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares',
#         'Doctorado universitario'], dtype=object),
#  array(['Total', 'Educación primaria e inferior',
#         'Primera etapa de educación secundaria y similar',
#         'Segunda etapa de educación secundaria y educación postsecundaria no superior',
#         'Educación superior'], dtype=object))

# %% [markdown]
# Observamos que la columna "Nivel de estudios" toma distintos valores en ambos dataframes, pero podemos hacer un mapeo, mediante un diccionario que permita asignar los mismos valores a dicha columna para ambos dataframes.

# %%
def reasignar_nivel_estudios(df, columna):
    """
    Reasigna los valores de una columna específica en un DataFrame 
    según un diccionario de mapeo predefinido.

    Args:
    df (pd.DataFrame): DataFrame que contiene la columna a modificar.
    columna (str): Nombre de la columna cuyos valores serán reasignados.

    Returns:
    pd.DataFrame: DataFrame con los valores de la columna reasignados.
    """
    # Crear un diccionario de mapeo para reasignar los valores
    mapeo_nivel_estudios = {
        'Total': 'Total',
        'Sin estudios': 'Educación primaria e inferior',
        'Educación primaria': 'Educación primaria e inferior',
        'Primera etapa de educación secundaria y similar': 'Primera etapa de educación secundaria y similar',
        'Segunda etapa de educación secundaria, con orientación general': 'Segunda etapa de educación secundaria y educación postsecundaria no superior',
        'Segunda etapa de educación secundaria con orientación profesional, Educación postsecundaria no superior': 'Segunda etapa de educación secundaria y educación postsecundaria no superior',
        'Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes': 'Educación superior',
        'Grados universitarios de hasta 240 créditos ECTS, diplomados universitarios y equivalentes': 'Educación superior',
        'Grados universitarios de más de 240 créditos ECTS, licenciados y equivalentes': 'Educación superior',
        'Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares': 'Educación superior',
        'Doctorado universitario': 'Educación superior'
    }

    # Reasignar los valores en la columna especificada
    df[columna] = df[columna].replace(mapeo_nivel_estudios)
    
    return df

# %%
df_nivel_educativo_municipios_grandes = reasignar_nivel_estudios(
    df_nivel_educativo_municipios_grandes, 'Nivel de estudios'
)

# %%
df_nivel_educativo_municipios_grandes['Nivel de estudios'].unique()
# Out:
# array(['Total', 'Educación primaria e inferior',
#        'Primera etapa de educación secundaria y similar',
#        'Segunda etapa de educación secundaria y educación postsecundaria no superior',
#        'Educación superior'], dtype=object)

# %%
df_nivel_educativo_municipios_pequenios['Nivel de estudios'].unique()
# Out:
# array(['Total', 'Educación primaria e inferior',
#        'Primera etapa de educación secundaria y similar',
#        'Segunda etapa de educación secundaria y educación postsecundaria no superior',
#        'Educación superior'], dtype=object)

# %% [markdown]
# Al mapear el nivel de estudios de los municipios pequeños en los grandes, se han generado filas con todos las celdas iguales excepto la de 'Total' en el dataframe de municipios grandes, las agrupamos sumando los totales.

# %%
# Agrupar por todas las columnas excepto "Total" y sumar los valores de "Total"
columnas_agrupacion = [col for col in df_nivel_educativo_municipios_grandes.columns if col != "Total"]
df_nivel_educativo_municipios_grandes = df_nivel_educativo_municipios_grandes.groupby(columnas_agrupacion, as_index=False)["Total"].sum()

# Mostrar las primeras filas del DataFrame actualizado
df_nivel_educativo_municipios_grandes.head()
# Out:
#                Municipios     Sexo País de nacimiento  \
# 0  01001 Alegría-Dulantzi  Hombres             España
# 1  01001 Alegría-Dulantzi  Hombres             España
# 2  01001 Alegría-Dulantzi  Hombres             España
# 3  01001 Alegría-Dulantzi  Hombres             España
# 4  01001 Alegría-Dulantzi  Hombres             España
#
#                                  Nivel de estudios  Periodo  Total
# 0                    Educación primaria e inferior     2021     76
# 1                    Educación primaria e inferior     2022     76
# 2                               Educación superior     2021    455
# 3                               Educación superior     2022    470
# 4  Primera etapa de educación secundaria y similar     2021    263

# %% [markdown]
# En el dataframe de nivel de estudios para muncipios pequeños vamos a añadir la columna "País de nacimiento" con el valor "Desconocido"

# %%
# Creamos una columna 'País de nacimiento' en el DataFrame de municipios pequeños
df_nivel_educativo_municipios_pequenios['País de nacimiento'] = "Desconocido"

# %%
df_nivel_educativo_municipios_pequenios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102570 entries, 0 to 102569
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Municipios          102570 non-null  object
#  1   Sexo                102570 non-null  object
#  2   Nivel de estudios   102570 non-null  object
#  3   Periodo             102570 non-null  int64
#  4   Total               102570 non-null  int64
#  5   País de nacimiento  102570 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 4.7+ MB

# %%
df_nivel_educativo_municipios_grandes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372960 entries, 0 to 372959
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Municipios          372960 non-null  object
#  1   Sexo                372960 non-null  object
#  2   País de nacimiento  372960 non-null  object
#  3   Nivel de estudios   372960 non-null  object
#  4   Periodo             372960 non-null  int64
#  5   Total               372960 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 17.1+ MB

# %% [markdown]
# Concatenamos ambos dataframes en uno que agrupe a todos los municipios

# %%
# Concatenar los DataFrames
df_nivel_educativo_municipios = pd.concat([df_nivel_educativo_municipios_grandes, df_nivel_educativo_municipios_pequenios], ignore_index=True)

# %%
df_nivel_educativo_municipios.sample(20)
# Out:
#                             Municipios     Sexo País de nacimiento  \
# 219361        29008 Alhaurín el Grande  Mujeres             España
# 166358                    22197 Robres  Mujeres             España
# 312444                    44086 Cretas  Mujeres              Total
# 339595                    46155 Llaurí  Hombres              Total
# 35751       06103 Puebla de la Calzada  Hombres              Total
# 249943                  33008 Cabrales  Hombres         Extranjera
# 348829                   47050 Cigales    Total         Extranjera
# 78866           10110 Losar de la Vera  Hombres              Total
# 474961           50278 Velilla de Ebro    Total        Desconocido
# 55198          08124 Mollet del Vallès  Hombres              Total
# 319058  45078 Huerta de Valdecarábanos  Hombres             España
# 432356       34131 Población de Arroyo  Mujeres        Desconocido
# 35304          06097 Orellana la Vieja  Hombres              Total
# 369141                  50153 Magallón  Mujeres              Total
# 88427         11902 San José del Valle  Mujeres         Extranjera
# 295042                  41074 Peñaflor  Hombres              Total
# 343310      46199 Pobla de Farnals, la  Mujeres              Total
# 22415                    04074 Pechina  Hombres             España
# 304374                43079 Masllorenç    Total              Total
# 252525                    33037 Mieres    Total         Extranjera
#
#                                         Nivel de estudios  Periodo  Total
# 219361                      Educación primaria e inferior     2022   1698
# 166358                                              Total     2021   2100
# 312444    Primera etapa de educación secundaria y similar     2021    920
# 339595    Primera etapa de educación secundaria y similar     2022   2400
# 35751                       Educación primaria e inferior     2022    429
# 249943                                 Educación superior     2022    380
# 348829                                              Total     2022   4010
# 78866   Segunda etapa de educación secundaria y educac...     2021   2000
# 474961                                              Total     2021    182
# 55198                                               Total     2021  21261
# 319058                                              Total     2021   6730
# 432356  Segunda etapa de educación secundaria y educac...     2022      3
# 35304     Primera etapa de educación secundaria y similar     2021    561
# 369141                      Educación primaria e inferior     2022   1060
# 88427   Segunda etapa de educación secundaria y educac...     2022    100
# 295042                                 Educación superior     2021   2300
# 343310                      Educación primaria e inferior     2021   5930
# 22415     Primera etapa de educación secundaria y similar     2022    673
# 304374    Primera etapa de educación secundaria y similar     2021   1620
# 252525    Primera etapa de educación secundaria y similar     2022   6240

# %%
df_nivel_educativo_municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475530 entries, 0 to 475529
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Municipios          475530 non-null  object
#  1   Sexo                475530 non-null  object
#  2   País de nacimiento  475530 non-null  object
#  3   Nivel de estudios   475530 non-null  object
#  4   Periodo             475530 non-null  int64
#  5   Total               475530 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 21.8+ MB

# %% [markdown]
# Los datos recogidos en el dataframe son de los años 2021 y 2022. Nos quedamos solos con los de 2022 que es el año objeto de nuestro estudio y eliminamos la columna pues nos quedamos con todos los datos de un mismo año

# %%
# Filtrar el DataFrame para conservar solo las filas donde "Periodo" es 2022
df_nivel_educativo_municipios = df_nivel_educativo_municipios[df_nivel_educativo_municipios['Periodo'] == 2022]
df_nivel_educativo_municipios.reset_index(drop=True, inplace=True)
# Eliminar la columna periodo
df_nivel_educativo_municipios.drop(columns=['Periodo'], inplace=True)

# %%
df_nivel_educativo_municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237765 entries, 0 to 237764
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Municipios          237765 non-null  object
#  1   Sexo                237765 non-null  object
#  2   País de nacimiento  237765 non-null  object
#  3   Nivel de estudios   237765 non-null  object
#  4   Total               237765 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 9.1+ MB

# %%
df_nivel_educativo_municipios.sample(20)
# Out:
#                               Municipios     Sexo País de nacimiento  \
# 122807                   32050 Monterrei  Hombres             España
# 160474                 45109 Navahermosa  Hombres             España
# 192533             09060 Busto de Bureba  Hombres        Desconocido
# 206220                   22115 Grado, El    Total        Desconocido
# 16145                     06057 Garlitos    Total         Extranjera
# 224958      42211 Villares de Soria, Los    Total        Desconocido
# 228071       44251 Villafranca del Campo  Mujeres        Desconocido
# 22027                     07042 Pollença  Mujeres         Extranjera
# 120192                 31254 Villafranca    Total              Total
# 209942                      25150 Oliola    Total        Desconocido
# 127232  33060 San Martín del Rey Aurelio  Mujeres             España
# 68789                  18057 Cúllar Vega  Mujeres              Total
# 178572                     48059 Mañaria  Hombres              Total
# 123762                      32072 Rúa, A  Hombres              Total
# 163614               45197 Villasequilla    Total         Extranjera
# 105449                 28080 Majadahonda  Hombres              Total
# 224641       42166 Santa Cruz de Yanguas    Total        Desconocido
# 48316         13031 Carrión de Calatrava    Total             España
# 214415            31210 Roncal/Erronkari  Hombres        Desconocido
# 14154                    06007 Alconchel  Mujeres         Extranjera
#
#                                         Nivel de estudios  Total
# 122807    Primera etapa de educación secundaria y similar   4680
# 160474                                              Total   1464
# 192533  Segunda etapa de educación secundaria y educac...     22
# 206220                                              Total    374
# 16145                       Educación primaria e inferior      1
# 224958  Segunda etapa de educación secundaria y educac...     11
# 228071                      Educación primaria e inferior     42
# 22027     Primera etapa de educación secundaria y similar    472
# 120192    Primera etapa de educación secundaria y similar    115
# 209942    Primera etapa de educación secundaria y similar     45
# 127232    Primera etapa de educación secundaria y similar   2681
# 68789                                               Total   3223
# 178572    Primera etapa de educación secundaria y similar    380
# 123762    Primera etapa de educación secundaria y similar   6250
# 163614                                              Total   2990
# 105449                                              Total  28089
# 224641                      Educación primaria e inferior      5
# 48316                                  Educación superior   6060
# 214415                                              Total    104
# 14154                                               Total     11

# %% [markdown]
# Procesamos el dataframe con la información de nivel educativo municipal para limpiarlo y dejarlo listo para el analisis.

# %%
def procesar_informacion_municipios(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel municipal, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Separa los códigos y nombres de comunidades y provincias en columnas distintas.
    2. Convierte las columnas 'Código comunidad' y 'Código provincia' a tipo int64.
    3. Reordena las columnas colocando los códigos y nombres de comunidades y provincias al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
        
    # 1. Separar código y nombre de los municipios         
    if 'Municipios' in df.columns:
        df[['Código municipio', 'Nombre municipio']] = df['Municipios'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Municipios'], inplace=True)
        
    # 2. Convertir la columna 'Código municipio' a tipo int64 si existe
    if 'Código municipio' in df.columns:
        df['Código municipio'] = df['Código municipio'].astype('int64')
    
    # 3. Reordenar las columnas para que los códigos y nombres aparezcan primero
    columnas_prioritarias = ['Código municipio', 'Nombre municipio']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_nivel_educativo_municipios = procesar_informacion_municipios(df_nivel_educativo_municipios)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_nivel_educativo_municipios.info())
df_nivel_educativo_municipios.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237765 entries, 0 to 237764
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Código municipio    237765 non-null  int64
#  1   Nombre municipio    237765 non-null  object
#  2   Sexo                237765 non-null  object
#  3   País de nacimiento  237765 non-null  object
#  4   Nivel de estudios   237765 non-null  object
#  5   Total               237765 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 10.9+ MB
# None
#     Código municipio  Nombre municipio     Sexo País de nacimiento  \
# 0               1001  Alegría-Dulantzi  Hombres             España
# 1               1001  Alegría-Dulantzi  Hombres             España
# 2               1001  Alegría-Dulantzi  Hombres             España
# 3               1001  Alegría-Dulantzi  Hombres             España
# 4               1001  Alegría-Dulantzi  Hombres             España
# 5               1001  Alegría-Dulantzi  Hombres         Extranjera
# 6               1001  Alegría-Dulantzi  Hombres         Extranjera
# 7               1001  Alegría-Dulantzi  Hombres         Extranjera
# 8               1001  Alegría-Dulantzi  Hombres         Extranjera
# 9               1001  Alegría-Dulantzi  Hombres         Extranjera
# 10              1001  Alegría-Dulantzi  Hombres              Total
# 11              1001  Alegría-Dulantzi  Hombres              Total
# 12              1001  Alegría-Dulantzi  Hombres              Total
# 13              1001  Alegría-Dulantzi  Hombres              Total
# 14              1001  Alegría-Dulantzi  Hombres              Total
# 15              1001  Alegría-Dulantzi  Mujeres             España
# 16              1001  Alegría-Dulantzi  Mujeres             España
# 17              1001  Alegría-Dulantzi  Mujeres             España
# 18              1001  Alegría-Dulantzi  Mujeres             España
# 19              1001  Alegría-Dulantzi  Mujeres             España
# 20              1001  Alegría-Dulantzi  Mujeres         Extranjera
# 21              1001  Alegría-Dulantzi  Mujeres         Extranjera
# 22              1001  Alegría-Dulantzi  Mujeres         Extranjera
# 23              1001  Alegría-Dulantzi  Mujeres         Extranjera
# 24              1001  Alegría-Dulantzi  Mujeres         Extranjera
# 25              1001  Alegría-Dulantzi  Mujeres              Total
# 26              1001  Alegría-Dulantzi  Mujeres              Total
# 27              1001  Alegría-Dulantzi  Mujeres              Total
# 28              1001  Alegría-Dulantzi  Mujeres              Total
# 29              1001  Alegría-Dulantzi  Mujeres              Total
# 30              1001  Alegría-Dulantzi    Total             España
# 31              1001  Alegría-Dulantzi    Total             España
# 32              1001  Alegría-Dulantzi    Total             España
# 33              1001  Alegría-Dulantzi    Total             España
# 34              1001  Alegría-Dulantzi    Total             España
# 35              1001  Alegría-Dulantzi    Total         Extranjera
# 36              1001  Alegría-Dulantzi    Total         Extranjera
# 37              1001  Alegría-Dulantzi    Total         Extranjera
# 38              1001  Alegría-Dulantzi    Total         Extranjera
# 39              1001  Alegría-Dulantzi    Total         Extranjera
# 40              1001  Alegría-Dulantzi    Total              Total
# 41              1001  Alegría-Dulantzi    Total              Total
# 42              1001  Alegría-Dulantzi    Total              Total
# 43              1001  Alegría-Dulantzi    Total              Total
# 44              1001  Alegría-Dulantzi    Total              Total
# 45              1002           Amurrio  Hombres             España
# 46              1002           Amurrio  Hombres             España
# 47              1002           Amurrio  Hombres             España
# 48              1002           Amurrio  Hombres             España
# 49              1002           Amurrio  Hombres             España
#
#                                     Nivel de estudios  Total
# 0                       Educación primaria e inferior     76
# 1                                  Educación superior    470
# 2     Primera etapa de educación secundaria y similar    253
# 3   Segunda etapa de educación secundaria y educac...    230
# 4                                               Total   1029
# 5                       Educación primaria e inferior     44
# 6                                  Educación superior     41
# 7     Primera etapa de educación secundaria y similar     81
# 8   Segunda etapa de educación secundaria y educac...     51
# 9                                               Total    217
# 10                      Educación primaria e inferior    120
# 11                                 Educación superior    511
# 12    Primera etapa de educación secundaria y similar    334
# 13  Segunda etapa de educación secundaria y educac...    281
# 14                                              Total   1246
# 15                      Educación primaria e inferior     89
# 16                                 Educación superior    477
# 17    Primera etapa de educación secundaria y similar    242
# 18  Segunda etapa de educación secundaria y educac...    178
# 19                                              Total    986
# 20                      Educación primaria e inferior     68
# 21                                 Educación superior     45
# 22    Primera etapa de educación secundaria y similar     41
# 23  Segunda etapa de educación secundaria y educac...     42
# 24                                              Total    196
# 25                      Educación primaria e inferior    157
# 26                                 Educación superior    522
# 27    Primera etapa de educación secundaria y similar    283
# 28  Segunda etapa de educación secundaria y educac...    220
# 29                                              Total   1182
# 30                      Educación primaria e inferior    165
# 31                                 Educación superior    947
# 32    Primera etapa de educación secundaria y similar    495
# 33  Segunda etapa de educación secundaria y educac...    408
# 34                                              Total   2015
# 35                      Educación primaria e inferior    112
# 36                                 Educación superior     86
# 37    Primera etapa de educación secundaria y similar    122
# 38  Segunda etapa de educación secundaria y educac...     93
# 39                                              Total    413
# 40                      Educación primaria e inferior    277
# 41                                 Educación superior   1033
# 42    Primera etapa de educación secundaria y similar    617
# 43  Segunda etapa de educación secundaria y educac...    501
# 44                                              Total   2428
# 45                      Educación primaria e inferior    418
# 46                                 Educación superior   1549
# 47    Primera etapa de educación secundaria y similar    812
# 48  Segunda etapa de educación secundaria y educac...   1065
# 49                                              Total   3844

# %%
df_nivel_educativo_municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237765 entries, 0 to 237764
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Código municipio    237765 non-null  int64
#  1   Nombre municipio    237765 non-null  object
#  2   Sexo                237765 non-null  object
#  3   País de nacimiento  237765 non-null  object
#  4   Nivel de estudios   237765 non-null  object
#  5   Total               237765 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 10.9+ MB

# %%
df_nivel_educativo_municipios.to_csv("datos_limpiados/municipios/nivel_educativo_municipios_limpio.csv", index=False)

# %% [markdown]
# ## Procesamos ahora el archivo que contiene la información provincial, autonómica y nacional del nivel educativo alcanzado.

# %%
df_nivel_educativo = pd.read_csv("datos/ine/nivel_educativo.csv", encoding= 'latin-1', sep=';')

# %%
df_nivel_educativo.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                              NaN        NaN
# 1  Total Nacional                              NaN        NaN
# 2  Total Nacional                              NaN        NaN
# 3  Total Nacional                              NaN        NaN
# 4  Total Nacional                              NaN        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado           Edad     Sexo  \
# 0              España      Doctorado universitario  15 y más años  Hombres
# 1              España      Doctorado universitario  15 y más años  Mujeres
# 2              España      Doctorado universitario  15 y más años    Total
# 3              España           Educación primaria  15 y más años  Hombres
# 4              España           Educación primaria  15 y más años  Mujeres
#
#    Periodo      Total
# 0     2022    197.035
# 1     2022    168.651
# 2     2022    365.686
# 3     2022  1.500.259
# 4     2022  2.120.412

# %% [markdown]
# Eliminamos las columna "Edad" y "Periodo que no son relevantes para nuestro análisis

# %%
# Eliminar las columnas 'Edad'
df_nivel_educativo.drop(columns=['Edad','Periodo'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_nivel_educativo.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                              NaN        NaN
# 1  Total Nacional                              NaN        NaN
# 2  Total Nacional                              NaN        NaN
# 3  Total Nacional                              NaN        NaN
# 4  Total Nacional                              NaN        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo      Total
# 0              España      Doctorado universitario  Hombres    197.035
# 1              España      Doctorado universitario  Mujeres    168.651
# 2              España      Doctorado universitario    Total    365.686
# 3              España           Educación primaria  Hombres  1.500.259
# 4              España           Educación primaria  Mujeres  2.120.412

# %% [markdown]
# Formateamos la columna "Total"

# %%
# Convertimos la columna "Total" a int64
df_nivel_educativo['Total'] = df_nivel_educativo['Total'].str.replace('.', '').astype('int64')
df_nivel_educativo.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                              NaN        NaN
# 1  Total Nacional                              NaN        NaN
# 2  Total Nacional                              NaN        NaN
# 3  Total Nacional                              NaN        NaN
# 4  Total Nacional                              NaN        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo    Total
# 0              España      Doctorado universitario  Hombres   197035
# 1              España      Doctorado universitario  Mujeres   168651
# 2              España      Doctorado universitario    Total   365686
# 3              España           Educación primaria  Hombres  1500259
# 4              España           Educación primaria  Mujeres  2120412

# %% [markdown]
# A partir del dataframe que estamos procesando vamos a crear 3, uno con la información nacional, otro con la información autonomica y otro con la información provincial.

# %%
def filtrar_dataframe_ine(df):
    """
    Filtra un DataFrame del ine en tres niveles: nacional, autonómico y provincial.

    Parámetros:
    df (pd.DataFrame): DataFrame que contiene las columnas 'Comunidades y Ciudades Autónomas' y 'Provincias'.

    Retorna:
    tuple: Tres DataFrames correspondientes a nivel nacional, autonómico y provincial.
    """
    # Nivel nacional: Filtramos donde "Comunidades y Ciudades Autónomas" sea NaN
    df_nacional = df[df['Comunidades y Ciudades Autónomas'].isna()].copy().reset_index(drop=True)

    # Nivel autonómico: Filtramos donde "Comunidades y Ciudades Autónomas" no sea NaN y "Provincias" sea NaN
    df_autonomico = df[df['Comunidades y Ciudades Autónomas'].notna() & df['Provincias'].isna()].copy().reset_index(drop=True)

    # Nivel provincial: Filtramos donde "Provincias" no sea NaN
    df_provincial = df[df['Provincias'].notna()].copy().reset_index(drop=True)

    return df_nacional, df_autonomico, df_provincial

# Lo aplicamos al DataFrame de nivel educativo:
df_nivel_educativo_nacional, df_nivel_educativo_comunidades, df_nivel_educativo_provincias = filtrar_dataframe_ine(df_nivel_educativo)

# %%
df_nivel_educativo_nacional.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                              NaN        NaN
# 1  Total Nacional                              NaN        NaN
# 2  Total Nacional                              NaN        NaN
# 3  Total Nacional                              NaN        NaN
# 4  Total Nacional                              NaN        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo    Total
# 0              España      Doctorado universitario  Hombres   197035
# 1              España      Doctorado universitario  Mujeres   168651
# 2              España      Doctorado universitario    Total   365686
# 3              España           Educación primaria  Hombres  1500259
# 4              España           Educación primaria  Mujeres  2120412

# %%
df_nivel_educativo_comunidades.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                     01 Andalucía        NaN
# 1  Total Nacional                     01 Andalucía        NaN
# 2  Total Nacional                     01 Andalucía        NaN
# 3  Total Nacional                     01 Andalucía        NaN
# 4  Total Nacional                     01 Andalucía        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo   Total
# 0              España      Doctorado universitario  Hombres   30241
# 1              España      Doctorado universitario  Mujeres   23208
# 2              España      Doctorado universitario    Total   53449
# 3              España           Educación primaria  Hombres  290619
# 4              España           Educación primaria  Mujeres  360800

# %%
df_nivel_educativo_provincias.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  \
# 0  Total Nacional                     01 Andalucía  04 Almería
# 1  Total Nacional                     01 Andalucía  04 Almería
# 2  Total Nacional                     01 Andalucía  04 Almería
# 3  Total Nacional                     01 Andalucía  04 Almería
# 4  Total Nacional                     01 Andalucía  04 Almería
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo  Total
# 0              España      Doctorado universitario  Hombres   1673
# 1              España      Doctorado universitario  Mujeres   1354
# 2              España      Doctorado universitario    Total   3027
# 3              España           Educación primaria  Hombres  28248
# 4              España           Educación primaria  Mujeres  29773

# %% [markdown]
# ## Limpiamos ahora  los datos de nivel educativo alcanzado por provincias.

# %%
df_nivel_educativo_provincias.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas  Provincias  \
# 0  Total Nacional                     01 Andalucía  04 Almería
# 1  Total Nacional                     01 Andalucía  04 Almería
# 2  Total Nacional                     01 Andalucía  04 Almería
# 3  Total Nacional                     01 Andalucía  04 Almería
# 4  Total Nacional                     01 Andalucía  04 Almería
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo  Total
# 0              España      Doctorado universitario  Hombres   1673
# 1              España      Doctorado universitario  Mujeres   1354
# 2              España      Doctorado universitario    Total   3027
# 3              España           Educación primaria  Hombres  28248
# 4              España           Educación primaria  Mujeres  29773

# %% [markdown]
# Procesamos el dataframe con la información provincial de nivel de educación

# %%
def procesar_informacion_provincias(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel provincial, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Elimina la columna "Total Nacional".
    2. Separa los códigos y nombres de comunidades y provincias en columnas distintas.
    3. Convierte las columnas 'Código comunidad' y 'Código provincia' a tipo int64.
    4. Reordena las columnas colocando los códigos y nombres de comunidades y provincias al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar la columna "Total Nacional"
    if "Total Nacional" in df.columns:
        df.drop(columns=["Total Nacional"], inplace=True)
           
    # 2. Separar código y nombre de comunidad y provincia
    if 'Comunidades y Ciudades Autónomas' in df.columns and 'Provincias' in df.columns:
        df[['Código comunidad', 'Nombre comunidad']] = df['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)
        df[['Código provincia', 'Nombre provincia']] = df['Provincias'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Comunidades y Ciudades Autónomas', 'Provincias'], inplace=True)

    # 3. Convertir las columnas 'Código comunidad' y 'Código provincia' a tipo int64 si existen
    for col in ['Código comunidad', 'Código provincia']:
        if col in df.columns:
            df[col] = df[col].astype('int64')
    
    # 4. Reordenar las columnas para que los códigos y nombres aparezcan primero
    columnas_prioritarias = ['Código comunidad', 'Nombre comunidad', 'Código provincia', 'Nombre provincia']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_nivel_educativo_provincias = procesar_informacion_provincias(df_nivel_educativo_provincias)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_nivel_educativo_provincias.info())
df_nivel_educativo_provincias.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148 entries, 0 to 5147
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Código comunidad              5148 non-null   int64
#  1   Nombre comunidad              5148 non-null   object
#  2   Código provincia              5148 non-null   int64
#  3   Nombre provincia              5148 non-null   object
#  4   Lugar de nacimiento           5148 non-null   object
#  5   Nivel de formación alcanzado  5148 non-null   object
#  6   Sexo                          5148 non-null   object
#  7   Total                         5148 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 321.9+ KB
# None
#    Código comunidad Nombre comunidad  Código provincia Nombre provincia  \
# 0                 1        Andalucía                 4          Almería
# 1                 1        Andalucía                 4          Almería
# 2                 1        Andalucía                 4          Almería
# 3                 1        Andalucía                 4          Almería
# 4                 1        Andalucía                 4          Almería
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo  Total
# 0              España      Doctorado universitario  Hombres   1673
# 1              España      Doctorado universitario  Mujeres   1354
# 2              España      Doctorado universitario    Total   3027
# 3              España           Educación primaria  Hombres  28248
# 4              España           Educación primaria  Mujeres  29773

# %% [markdown]
# Ceuta y Melilla son ciudades autónomas tenemos que decidir que hacer con ellas

# %%
"""
# Filtrar el DataFrame eliminando las filas donde el Nombre provincia sea "Ceuta" o "Melilla"
df_nivel_educativo_provincias = df_nivel_educativo_provincias[
    ~df_nivel_educativo_provincias["Nombre provincia"].isin(["Ceuta", "Melilla"])
]

# Redf_nivel_educativo_provinciassetear el índice después de eliminar las filas no deseadas
df_censo_2022_provincial = df_nivel_educativo_provincias.reset_index(drop=True)
"""
# Out:
# '\n# Filtrar el DataFrame eliminando las filas donde el Nombre provincia sea "Ceuta" o "Melilla"\ndf_nivel_educativo_provincias = df_nivel_educativo_provincias[\n    ~df_nivel_educativo_provincias["Nombre provincia"].isin(["Ceuta", "Melilla"])\n]\n\n# Redf_nivel_educativo_provinciassetear el índice después de eliminar las filas no deseadas\ndf_censo_2022_provincial = df_nivel_educativo_provincias.reset_index(drop=True)\n'

# %%
# Guardamos el DataFrame en un archivo CSV
df_nivel_educativo_provincias.to_csv("datos_limpiados/provincias/nivel_educativo_provincias_limpio.csv", index=False)

# %% [markdown]
# ## Limpiamos ahora los datos de nivel educativo alcanzado por comunidades autónomas

# %%
df_nivel_educativo_comunidades.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                     01 Andalucía        NaN
# 1  Total Nacional                     01 Andalucía        NaN
# 2  Total Nacional                     01 Andalucía        NaN
# 3  Total Nacional                     01 Andalucía        NaN
# 4  Total Nacional                     01 Andalucía        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo   Total
# 0              España      Doctorado universitario  Hombres   30241
# 1              España      Doctorado universitario  Mujeres   23208
# 2              España      Doctorado universitario    Total   53449
# 3              España           Educación primaria  Hombres  290619
# 4              España           Educación primaria  Mujeres  360800

# %% [markdown]
# La columna 'Provincias' está vacía así que la eliminaos

# %%
# Eliminar la columna 'Provincias'
df_nivel_educativo_comunidades.drop(columns=['Provincias'], inplace=True)

# Mostrar las primeras filas del DataFrame actualizado
df_nivel_educativo_comunidades.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Lugar de nacimiento  \
# 0  Total Nacional                     01 Andalucía              España
# 1  Total Nacional                     01 Andalucía              España
# 2  Total Nacional                     01 Andalucía              España
# 3  Total Nacional                     01 Andalucía              España
# 4  Total Nacional                     01 Andalucía              España
#
#   Nivel de formación alcanzado     Sexo   Total
# 0      Doctorado universitario  Hombres   30241
# 1      Doctorado universitario  Mujeres   23208
# 2      Doctorado universitario    Total   53449
# 3           Educación primaria  Hombres  290619
# 4           Educación primaria  Mujeres  360800

# %% [markdown]
# Procesamos el Dataframe con la información autonómica.

# %%
def procesar_informacion_comunidades(df):
    """
    Realiza el procesamiento de un Dataframe con información a nivel de comunidad autónoma, extraida del INE,
    aplicando las siguientes transformaciones:
    1. Elimina la columna "Total Nacional".
    2. Separa los códigos y nombres de comunidades en columnas distintas.
    3. Convierte la columna 'Código comunidad' a tipo int64.
    4. Reordena las columnas colocando los códigos y nombres de comunidades al inicio.
        
    Parámetros:
        df (pd.DataFrame): DataFrame con la información de nivel educativo por provincias.
    
    Retorna:
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar la columna "Total Nacional"
    if "Total Nacional" in df.columns:
        df.drop(columns=["Total Nacional"], inplace=True)
           
    # 2. Separar código y nombre de comunidad
    if 'Comunidades y Ciudades Autónomas' in df.columns:
        df[['Código comunidad', 'Nombre comunidad']] = df['Comunidades y Ciudades Autónomas'].str.split(pat=' ', n=1, expand=True)
        df.drop(columns=['Comunidades y Ciudades Autónomas'], inplace=True)

    # 3. Convertir la columnas 'Código comunidad' a tipo int64 si existe
    for col in ['Código comunidad']:
        if col in df.columns:
            df[col] = df[col].astype('int64')
    
    # 4. Reordenar las columnas para que el codigo y nombre de comunidad aparezcan primero
    columnas_prioritarias = ['Código comunidad', 'Nombre comunidad']
    columnas_ordenadas = columnas_prioritarias + [col for col in df.columns if col not in columnas_prioritarias]
    df = df[columnas_ordenadas]
        
    return df

# Aplicar la función al DataFrame
df_nivel_educativo_comunidades = procesar_informacion_comunidades(df_nivel_educativo_comunidades)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_nivel_educativo_comunidades.info())
df_nivel_educativo_comunidades.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1881 entries, 0 to 1880
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Código comunidad              1881 non-null   int64
#  1   Nombre comunidad              1881 non-null   object
#  2   Lugar de nacimiento           1881 non-null   object
#  3   Nivel de formación alcanzado  1881 non-null   object
#  4   Sexo                          1881 non-null   object
#  5   Total                         1881 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 88.3+ KB
# None
#    Código comunidad Nombre comunidad Lugar de nacimiento  \
# 0                 1        Andalucía              España
# 1                 1        Andalucía              España
# 2                 1        Andalucía              España
# 3                 1        Andalucía              España
# 4                 1        Andalucía              España
#
#   Nivel de formación alcanzado     Sexo   Total
# 0      Doctorado universitario  Hombres   30241
# 1      Doctorado universitario  Mujeres   23208
# 2      Doctorado universitario    Total   53449
# 3           Educación primaria  Hombres  290619
# 4           Educación primaria  Mujeres  360800

# %%
# Guardamos el DataFrame en un archivo CSV
df_nivel_educativo_comunidades.to_csv("datos_limpiados/comunidades/nivel_educativo_comunidades_limpio.csv", index=False)

# %% [markdown]
# ## Limpiamos el dataframe con la información del nivel educativo a nivel nacional

# %%
df_nivel_educativo_nacional.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 0  Total Nacional                              NaN        NaN
# 1  Total Nacional                              NaN        NaN
# 2  Total Nacional                              NaN        NaN
# 3  Total Nacional                              NaN        NaN
# 4  Total Nacional                              NaN        NaN
#
#   Lugar de nacimiento Nivel de formación alcanzado     Sexo    Total
# 0              España      Doctorado universitario  Hombres   197035
# 1              España      Doctorado universitario  Mujeres   168651
# 2              España      Doctorado universitario    Total   365686
# 3              España           Educación primaria  Hombres  1500259
# 4              España           Educación primaria  Mujeres  2120412

# %%
df_nivel_educativo_nacional.sample(20)
# Out:
#     Total Nacional Comunidades y Ciudades Autónomas Provincias  \
# 19  Total Nacional                              NaN        NaN
# 86  Total Nacional                              NaN        NaN
# 40  Total Nacional                              NaN        NaN
# 70  Total Nacional                              NaN        NaN
# 58  Total Nacional                              NaN        NaN
# 38  Total Nacional                              NaN        NaN
# 93  Total Nacional                              NaN        NaN
# 48  Total Nacional                              NaN        NaN
# 78  Total Nacional                              NaN        NaN
# 69  Total Nacional                              NaN        NaN
# 75  Total Nacional                              NaN        NaN
# 25  Total Nacional                              NaN        NaN
# 14  Total Nacional                              NaN        NaN
# 10  Total Nacional                              NaN        NaN
# 7   Total Nacional                              NaN        NaN
# 12  Total Nacional                              NaN        NaN
# 57  Total Nacional                              NaN        NaN
# 0   Total Nacional                              NaN        NaN
# 74  Total Nacional                              NaN        NaN
# 97  Total Nacional                              NaN        NaN
#
#    Lugar de nacimiento                       Nivel de formación alcanzado  \
# 19              España    Primera etapa de educación secundaria y similar
# 86               Total    Primera etapa de educación secundaria y similar
# 40          Extranjera  Enseñanzas de formación profesional, artes plá...
# 70               Total                                 Educación primaria
# 58          Extranjera  Segunda etapa de educación secundaria, con ori...
# 38          Extranjera                                 Educación primaria
# 93               Total                                       Sin estudios
# 48          Extranjera  Másteres, especialidades en Ciencias de la Sal...
# 78               Total  Grados universitarios de más de 240 créditos E...
# 69               Total                                 Educación primaria
# 75               Total  Grados universitarios de hasta 240 créditos EC...
# 25              España  Segunda etapa de educación secundaria, con ori...
# 14              España  Grados universitarios de más de 240 créditos E...
# 10              España  Grados universitarios de hasta 240 créditos EC...
# 7               España  Enseñanzas de formación profesional, artes plá...
# 12              España  Grados universitarios de más de 240 créditos E...
# 57          Extranjera  Segunda etapa de educación secundaria, con ori...
# 0               España                            Doctorado universitario
# 74               Total  Enseñanzas de formación profesional, artes plá...
# 97               Total                                              Total
#
#        Sexo     Total
# 19  Mujeres   5026080
# 86    Total  12346077
# 40  Mujeres    182164
# 70  Mujeres   2758557
# 58  Mujeres    717845
# 38    Total   1232266
# 93  Hombres    652934
# 48  Hombres     57373
# 78  Hombres   1668772
# 69  Hombres   2094380
# 75  Hombres   1721889
# 25  Mujeres   1810395
# 14    Total   3032421
# 10  Mujeres   2071162
# 7   Mujeres   1513408
# 12  Hombres   1407195
# 57  Hombres    619983
# 0   Hombres    197035
# 74    Total   3632680
# 97  Mujeres  21001815

# %% [markdown]
# Limpiamos el dataframe

# %%
def procesar_informacion_nacional(df):
    """
    Realiza el procesamiento de un DataFrame con información a nivel nacional, extraída del INE,
    aplicando las siguientes transformaciones:

    1. Elimina las columnas 'Provincias' y 'Comunidades y Ciudades Autónomas'.
    2. Renombra la columna "Total Nacional" a "Nombre del país".
    3. Asigna el valor "España" a todas las filas en la columna "Nombre del país".
        
    Parámetros:
    -----------
        df (pd.DataFrame): DataFrame con la información de nivel educativo a nivel nacional.

    Retorna:
    --------
        pd.DataFrame: DataFrame transformado con las modificaciones aplicadas.
    """
    df = df.copy()  # Crear una copia para no modificar el original
    
    # 1. Eliminar las columnas 'Provincias' y 'Comunidades y Ciudades Autónomas' si existen
    columnas_a_eliminar = ['Comunidades y Ciudades Autónomas', 'Provincias']
    df.drop(columns=[col for col in columnas_a_eliminar if col in df.columns], inplace=True)

    # 2. Renombrar la columna "Total Nacional" a "Nombre del país" si existe
    if "Total Nacional" in df.columns:
        df.rename(columns={"Total Nacional": "Nombre del país"}, inplace=True)

    # 3. Asignar el valor "España" a todas las filas en la columna "Nombre del país"
    if "Nombre del país" in df.columns:
        df["Nombre del país"] = "España"

    return df

# Aplicar la función al DataFrame
df_nivel_educativo_nacional = procesar_informacion_nacional(df_nivel_educativo_nacional)

# Mostrar información y primeras filas del DataFrame actualizado
print(df_nivel_educativo_nacional.info())
df_nivel_educativo_nacional.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Nombre del país               99 non-null     object
#  1   Lugar de nacimiento           99 non-null     object
#  2   Nivel de formación alcanzado  99 non-null     object
#  3   Sexo                          99 non-null     object
#  4   Total                         99 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
# None
#   Nombre del país Lugar de nacimiento Nivel de formación alcanzado     Sexo  \
# 0          España              España      Doctorado universitario  Hombres
# 1          España              España      Doctorado universitario  Mujeres
# 2          España              España      Doctorado universitario    Total
# 3          España              España           Educación primaria  Hombres
# 4          España              España           Educación primaria  Mujeres
#
#      Total
# 0   197035
# 1   168651
# 2   365686
# 3  1500259
# 4  2120412

# %%
df_nivel_educativo_nacional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Nombre del país               99 non-null     object
#  1   Lugar de nacimiento           99 non-null     object
#  2   Nivel de formación alcanzado  99 non-null     object
#  3   Sexo                          99 non-null     object
#  4   Total                         99 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
# Guardamos el DataFrame en un archivo CSV
df_nivel_educativo_nacional.to_csv("datos_limpiados/nacionales/nivel_educativo_nacional_limpio.csv", index=False)
