# %%
# Para trabajar con regex
# -----------------------------------------------------------------------
import re

# Para trabajar con ficheros
# -----------------------------------------------------------------------
import os


# Para trabajar con los DataFrames
# -----------------------------------------------------------------------
import pandas as pd

# Para poner barras progreso
# -----------------------------------------------------------------------
from tqdm import tqdm



# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Ignorar warings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# Librerias para generar gráficas
# ----------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tasa_repetidores_primaria=pd.read_csv("datos/ministerio-educacion/tasa_alumnado_repetidor_primaria.csv", encoding= 'latin-1', sep=';')

# %%
df_tasa_repetidores_primaria.sample(20)
# Out:
#             Titularidad         Sexo Comunidad autónoma/provincia    Curso  \
# 1264  TODOS LOS CENTROS      Mujeres         14 MURCIA, REGIÓN DE   Cuarto
# 3848   CENTROS PRIVADOS      Mujeres               11 EXTREMADURA   Quinto
# 1178  TODOS LOS CENTROS      Mujeres             Alicante/Alacant  Segundo
# 708   TODOS LOS CENTROS      Hombres                       Girona  Primero
# 3582   CENTROS PRIVADOS      Mujeres                         Jaén   Quinto
# 2899   CENTROS PRIVADOS  AMBOS SEXOS                  09 CATALUÑA  Primero
# 3709   CENTROS PRIVADOS      Mujeres                    Salamanca    Sexto
# 2322   CENTROS PÚBLICOS      Mujeres                  05 CANARIAS   Quinto
# 449   TODOS LOS CENTROS      Hombres                 01 ANDALUCÍA  Primero
# 1660   CENTROS PÚBLICOS  AMBOS SEXOS                   12 GALICIA  Primero
# 3084   CENTROS PRIVADOS  AMBOS SEXOS                   19 MELILLA   Cuarto
# ...

# %%
df_tasa_repetidores_secundaria=pd.read_csv("datos/ministerio-educacion/tasa_alumnado_repetidor_secundaria.csv", sep=';')

# %%
df_tasa_repetidores_secundaria.sample(20)
# Out:
#             Titularidad         Sexo Comunidad autónoma/provincia    Curso  \
# 396   TODOS LOS CENTROS      Hombres                  05 CANARIAS  Primero
# 1161   CENTROS PÚBLICOS  AMBOS SEXOS           Castellón/Castelló  Primero
# 74    TODOS LOS CENTROS  AMBOS SEXOS   03 ASTURIAS, PRINCIPADO DE   Cuarto
# 372   TODOS LOS CENTROS      Hombres                       Huesca  Segundo
# 862   TODOS LOS CENTROS      Mujeres                      Badajoz  Segundo
# 2657   CENTROS PRIVADOS      Mujeres                        Soria  Segundo
# 1759   CENTROS PÚBLICOS      Mujeres                  09 CATALUÑA   Cuarto
# 2158   CENTROS PRIVADOS  AMBOS SEXOS      13 MADRID, COMUNIDAD DE  Tercero
# 1890   CENTROS PRIVADOS  AMBOS SEXOS                     00 TOTAL    Total
# 283   TODOS LOS CENTROS  AMBOS SEXOS                16 PAÍS VASCO  Tercero
# 1672   CENTROS PÚBLICOS      Mujeres                 06 CANTABRIA  Segundo
# ...

# %%
df_tasa_repetidores_bachillerato=pd.read_csv("datos/ministerio-educacion/tasa_alumnado_repetidor_bachillerato.csv", sep=';')

# %%
df_tasa_repetidores_bachillerato.sample(20)
# Out:
#             Titularidad         Sexo Comunidad autónoma/provincia  \
# 943    CENTROS PÚBLICOS      Hombres                   19 MELILLA
# 481   TODOS LOS CENTROS      Mujeres                  Guadalajara
# 1069   CENTROS PÚBLICOS      Mujeres      10 COMUNITAT VALENCIANA
# 286   TODOS LOS CENTROS      Hombres                  Ciudad Real
# 1216   CENTROS PRIVADOS  AMBOS SEXOS                        Soria
# 998    CENTROS PÚBLICOS      Mujeres                   Las Palmas
# 1334   CENTROS PRIVADOS      Hombres                        Cádiz
# 1683   CENTROS PRIVADOS      Mujeres                  Araba/Álava
# 644    CENTROS PÚBLICOS  AMBOS SEXOS                    Salamanca
# 893    CENTROS PÚBLICOS      Hombres               11 EXTREMADURA
# 1518   CENTROS PRIVADOS      Mujeres                      Almería
# 170   TODOS LOS CENTROS  AMBOS SEXOS                16 PAÍS VASCO
# 134   TODOS LOS CENTROS  AMBOS SEXOS            Valencia/València
# ...
